# %%
from sqlalchemy import create_engine

# %%
from datetime import datetime

from sqlalchemy import (MetaData, Table, Column, Integer, Numeric, String,
                        DateTime, ForeignKey, Boolean, Text,Date,LargeBinary)
metadata = MetaData()

# %%
customers = Table('customers',metadata,
 Column('CustomerID', Integer(), primary_key=True),
 Column('CustomerName', Text()),
 Column('ContactName', Text()),
 Column('Address', Text()),
 Column('City', Text()),
 Column('PostalCode', Text()),
 Column('Country',Text()),
)

# %%
category = Table('category',metadata,
 Column('CategoryID', Integer(), primary_key=True),
 Column('CategoryName', Text()),
 Column('Description', Text()),
 
)

# %%
supplier = Table('supplier',metadata,
 Column('SupplierID', Integer(), primary_key=True),
 Column('SupplierName', Text()),
 Column('ContactName', Text()),
 Column('Address', Text()),
 Column('City', Text()),
 Column('PostalCode', Text()),
 Column('Country', Text()),
 Column('Phone', Text()),
)

# %%
product = Table('product',metadata,
 Column('ProductID', Integer(), primary_key=True),
 Column('ProductName', Text()),
 Column('SupplierID', Integer(), ForeignKey('supplier.SupplierID')),
 Column('CategoryID', Integer(), ForeignKey('category.CategoryID')),
 Column('Unit', Text()),
 Column('Price', Numeric()),
)

# %%
shipper = Table('shipper',metadata,
 Column('ShipperID', Integer(), primary_key=True),
 Column('ShipperName', Text()),
 Column('Phone', Text()),
 
)

# %%
employee = Table('employee',metadata,
 Column('EmployeeID', Integer(), primary_key=True),
 Column('LastName', Text()),
 Column('FirstName', Text()),
 Column('BirthDate', Date()),
 Column('Photo', LargeBinary()),
 Column('Notes', Text()),
)

# %%
orders = Table('orders',metadata,
 Column('OrderID', Integer(), primary_key=True),
 Column('CustomerID', Integer(),ForeignKey('customers.CustomerID')),
 Column('EmployeeID', Integer() ,ForeignKey('employee.EmployeeID')) ,
 Column('OrderDate', Date()),
 Column('ShipperID', Integer(),ForeignKey('shipper.ShipperID') ),
)

# %%
order_detail = Table('order_detail',metadata,
 Column('OrderDetailID', Integer(), primary_key=True),
 Column('OrderID', Integer(), ForeignKey('orders.OrderID')),
 Column('ProductID', Integer(),ForeignKey('product.ProductID') ),
 Column('Quantity', Integer()),
 
)

# %%
engine = create_engine('sqlite:///customer.db', echo=False)

# %%
metadata.create_all(engine)

# %%
connection = engine.connect()

# %%
import pandas as pd

# %%
df_category = pd.read_csv("C:/Users/user/Downloads/Categories - Sheet1.csv")

# %%
df_employee = pd.read_csv("C:/Users/user/Downloads/Employee - Sheet1.csv")

# %%
df_order_detail = pd.read_csv("C:/Users/user/Downloads/Order_details.csv")

# %%
df_product = pd.read_csv("C:/Users/user/Downloads/Products - Sheet1.csv")

# %%
df_shipper = pd.read_csv("C:/Users/user/Downloads/Shipper - Sheet1.csv")

# %%
df_supplier = pd.read_csv("C:/Users/user/Downloads/Suppliers - Sheet1.csv")

# %%
df_customers = pd.read_csv("C:/Users/user/Downloads/Customers - Sheet1.csv")
df_customers.head()
# Out:
#    CustomerID                        CustomerName         ContactName  \
# 0           1                 Alfreds Futterkiste        Maria Anders
# 1           2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2           3             Antonio Moreno Taquería      Antonio Moreno
# 3           4                     Around the Horn        Thomas Hardy
# 4           5                  Berglunds snabbköp  Christina Berglund
#
#                          Address         City PostalCode  Country
# 0                  Obere Str. 57       Berlin      12209  Germany
# 1  Avda. de la Constitución 2222  México D.F.      05021   Mexico
# 2                 Mataderos 2312  México D.F.      05023   Mexico
# 3                120 Hanover Sq.       London    WA1 1DP       UK
# 4                 Berguvsvägen 8        Luleå   S-958 22   Sweden

# %%
df_customers.to_sql('customers', con=engine, if_exists='append',index=False)

# %%
df_orders = pd.read_csv("C:/Users/user/Downloads/Orders.csv")
df_orders.head()
# Out:
#    OrderID  CustomerID  EmployeeID   OrderDate  ShipperID
# 0    10248          90           5  1996-07-04          3
# 1    10249          81           6  1996-07-05          1
# 2    10250          34           4  1996-07-08          2
# 3    10251          84           3  1996-07-08          1
# 4    10252          76           4  1996-07-09          2

# %%
df_orders.to_sql('orders', con=engine, if_exists='append',index=False)

# %%
df_category.to_sql('category', con=engine, if_exists='append',index=False)

# %%
df_employee.to_sql('employee', con=engine, if_exists='append',index=False)

# %%
df_order_detail.to_sql('order_detail', con=engine, if_exists='append',index=False)

# %%
df_product.to_sql('product', con=engine, if_exists='append',index=False)

# %%
df_shipper.to_sql('shipper', con=engine, if_exists='append',index=False)

# %%
df_supplier.to_sql('supplier', con=engine, if_exists='append',index=False)

# %%
from sqlalchemy.sql import select

# %%
s = select([customers])

# %%
str(s)
# Out:
# 'SELECT customers."CustomerID", customers."CustomerName", customers."ContactName", customers."Address", customers."City", customers."PostalCode", customers."Country" \nFROM customers'

# %%
rp = connection.execute(s)

# %%
results = rp.fetchall()

# %%
first_row = results[0]
first_row
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')

# %%
first_row[1]
# Out:
# 'Alfreds Futterkiste'

# %%
first_row.CustomerName
# Out:
# 'Alfreds Futterkiste'

# %%
first_row[customers.c.CustomerName]
# Out:
# 'Alfreds Futterkiste'

# %%
x = customers.select()
x = x.limit(20)

# %%
rp = connection.execute(x)

# %%
for record in rp:
    print(record.CustomerName)
# Out:
# Alfreds Futterkiste
# Ana Trujillo Emparedados y helados
# Antonio Moreno Taquería
# Around the Horn
# Berglunds snabbköp
# Blauer See Delikatessen
# Blondel père et fils
# Bólido Comidas preparadas
# Bon app'
# Bottom-Dollar Marketse
# B's Beverages
# Cactus Comidas para llevar
# Centro comercial Moctezuma
# Chop-suey Chinese
# Comércio Mineiro
# Consolidated Holdings
# Drachenblut Delikatessend
# Du monde entier
# Eastern Connection
# Ernst Handel

# %%
v = select([customers.c.CustomerName, customers.c.ContactName])
v = v.limit(20)
rp = connection.execute(v)
print(rp.keys())
results = rp.fetchall()
# Out:
# ['CustomerName', 'ContactName']

# %%
results
# Out:
# [('Alfreds Futterkiste', 'Maria Anders'),
#  ('Ana Trujillo Emparedados y helados', 'Ana Trujillo'),
#  ('Antonio Moreno Taquería', 'Antonio Moreno'),
#  ('Around the Horn', 'Thomas Hardy'),
#  ('Berglunds snabbköp', 'Christina Berglund'),
#  ('Blauer See Delikatessen', 'Hanna Moos'),
#  ('Blondel père et fils', 'Frédérique Citeaux'),
#  ('Bólido Comidas preparadas', 'Martín Sommer'),
#  ("Bon app'", 'Laurence Lebihans'),
#  ('Bottom-Dollar Marketse', 'Elizabeth Lincoln'),
#  ("B's Beverages", 'Victoria Ashworth'),
#  ('Cactus Comidas para llevar', 'Patricio Simpson'),
#  ('Centro comercial Moctezuma', 'Francisco Chang'),
#  ('Chop-suey Chinese', 'Yang Wang'),
#  ('Comércio Mineiro', 'Pedro Afonso'),
#  ('Consolidated Holdings', 'Elizabeth Brown'),
#  ('Drachenblut Delikatessend', 'Sven Ottlieb'),
#  ('Du monde entier', 'Janine Labrune'),
#  ('Eastern Connection', 'Ann Devon'),
#  ('Ernst Handel', 'Roland Mendel')]

# %%
from sqlalchemy import desc
s = select([customers.c.CustomerID,customers.c.CustomerName, customers.c.ContactName])
s = s.order_by(desc(customers.c.CustomerID))
rp = connection.execute(s)
results =rp.fetchall()
results
# Out:
# [(91, 'Wolski', 'Zbyszek'),
#  (90, 'Wilman Kala', 'Matti Karttunen'),
#  (89, 'White Clover Markets', 'Karl Jablonski'),
#  (88, 'Wellington Importadora', 'Paula Parente'),
#  (87, 'Wartian Herkku', 'Pirkko Koskitalo'),
#  (86, 'Die Wandernde Kuh', 'Rita Müller'),
#  (85, 'Vins et alcools Chevalier', 'Paul Henriot'),
#  (84, 'Victuailles en stock', 'Mary Saveley'),
#  (83, 'Vaffeljernet', 'Palle Ibsen'),
#  (82, "Trail's Head Gourmet Provisioners", 'Helvetius Nagy'),
#  (81, 'Tradição Hipermercados', 'Anabela Domingues'),
#  (80, 'Tortuga Restaurante', 'Miguel Angel Paolino'),
#  (79, 'Toms Spezialitäten', 'Karin Josephs'),
#  (78, 'The Cracker Box', 'Liu Wong'),
#  (77, 'The Big Cheese', 'Liz Nixon'),
#  (76, 'Suprêmes délices', 'Pascale Cartrain'),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger'),
#  (74, 'Spécialités du monde', 'Dominique Perrier'),
#  (73, 'Simons bistro', 'Jytte Petersen'),
#  (72, 'Seven Seas Imports', 'Hari Kumar'),
#  (71, 'Save-a-lot Markets', 'Jose Pavarotti'),
#  (70, 'Santé Gourmet', 'Jonas Bergulfsen'),
#  (69, 'Romero y tomillo', 'Alejandra Camino'),
#  (68, 'Richter Supermarkt', 'Michael Holz'),
#  (67, 'Ricardo Adocicados', 'Janete Limeira'),
#  (66, 'Reggiani Caseifici', 'Maurizio Moroni'),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson'),
#  (64, 'Rancho grande', 'Sergio Gutiérrez'),
#  (63, 'QUICK-Stop', 'Horst Kloss'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho'),
#  (61, 'Que Delícia', 'Bernardo Batista'),
#  (60, 'Princesa Isabel Vinhoss', 'Isabel de Castro'),
#  (59, 'Piccolo und mehr', 'Georg Pipps'),
#  (58, 'Pericles Comidas clásicas', 'Guillermo Fernández'),
#  (57, 'Paris spécialités', 'Marie Bertrand'),
#  (56, 'Ottilies Käseladen', 'Henriette Pfalzheim'),
#  (55, 'Old World Delicatessen', 'Rene Phillips'),
#  (54, 'Océano Atlántico Ltda.', 'Yvonne Moncada'),
#  (53, 'North/South', 'Simon Crowther'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer'),
#  (51, 'Mère Paillarde', 'Jean Fresnière'),
#  (50, 'Maison Dewey', 'Catherine Dewey'),
#  (49, 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson'),
#  (47, 'LINO-Delicateses', 'Felipe Izquierdo'),
#  (46, 'LILA-Supermercado', 'Carlos González'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres'),
#  (44, 'Lehmanns Marktstand', 'Renate Messner'),
#  (43, 'Lazy K Kountry Store', 'John Steel'),
#  (42, 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri'),
#  (41, "La maison d'Asie", 'Annette Roulet'),
#  (40, "La corne d'abondance", 'Daniel Tonini'),
#  (39, 'Königlich Essen', 'Philip Cramer'),
#  (38, 'Island Trading', 'Helen Bennett'),
#  (37, 'Hungry Owl All-Night Grocers', 'Patricia McKenna'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer'),
#  (35, 'HILARIÓN-Abastos', 'Carlos Hernández'),
#  (34, 'Hanari Carnes', 'Mario Pontes'),
#  (33, 'GROSELLA-Restaurante', 'Manuel Pereira'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca'),
#  (30, 'Godos Cocina Típica', 'José Pedro Freyre'),
#  (29, 'Galería del gastrónomo', 'Eduardo Saavedra'),
#  (28, 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez'),
#  (27, 'Franchi S.p.A.', 'Paolo Accorti'),
#  (26, 'France restauration', 'Carine Schmitt'),
#  (25, 'Frankenversand', 'Peter Franken'),
#  (24, 'Folk och fä HB', 'Maria Larsson'),
#  (23, 'Folies gourmandes', 'Martine Rancé'),
#  (22, 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz'),
#  (20, 'Ernst Handel', 'Roland Mendel'),
#  (19, 'Eastern Connection', 'Ann Devon'),
#  (18, 'Du monde entier', 'Janine Labrune'),
#  (17, 'Drachenblut Delikatessend', 'Sven Ottlieb'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown'),
#  (15, 'Comércio Mineiro', 'Pedro Afonso'),
#  (14, 'Chop-suey Chinese', 'Yang Wang'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang'),
#  (12, 'Cactus Comidas para llevar', 'Patricio Simpson'),
#  (11, "B's Beverages", 'Victoria Ashworth'),
#  (10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln'),
#  (9, "Bon app'", 'Laurence Lebihans'),
#  (8, 'Bólido Comidas preparadas', 'Martín Sommer'),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund'),
#  (4, 'Around the Horn', 'Thomas Hardy'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo'),
#  (1, 'Alfreds Futterkiste', 'Maria Anders')]

# %%
from sqlalchemy import desc
s = select([customers])
s = s.order_by(desc(customers.c.CustomerName)).limit(20)
rp = connection.execute(s)
results =rp.fetchall()
results
# Out:
# [(91, 'Wolski', 'Zbyszek', 'ul. Filtrowa 68', 'Walla', '01-012', 'Poland'),
#  (90, 'Wilman Kala', 'Matti Karttunen', 'Keskuskatu 45', 'Helsinki', '21240', 'Finland'),
#  (89, 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA'),
#  (88, 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil'),
#  (87, 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland'),
#  (85, 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France'),
#  (84, 'Victuailles en stock', 'Mary Saveley', '2, rue du Commerce', 'Lyon', '69004', 'France'),
#  (83, 'Vaffeljernet', 'Palle Ibsen', 'Smagsløget 45', 'Århus', '8200', 'Denmark'),
#  (82, "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', '722 DaVinci Blvd.', 'Kirkland', '98034', 'USA'),
#  (81, 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro, 414', 'São Paulo', '05634-030', 'Brazil'),
#  (80, 'Tortuga Restaurante', 'Miguel Angel Paolino', 'Avda. Azteca 123', 'México D.F.', '05033', 'Mexico'),
#  (79, 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany'),
#  (78, 'The Cracker Box', 'Liu Wong', '55 Grizzly Peak Rd.', 'Butte', '59801', 'USA'),
#  (77, 'The Big Cheese', 'Liz Nixon', '89 Jefferson Way Suite 2', 'Portland', '97201', 'USA'),
#  (76, 'Suprêmes délices', 'Pascale Cartrain', 'Boulevard Tirou, 255', 'Charleroi', 'B-6000', 'Belgium'),
#  (74, 'Spécialités du monde', 'Dominique Perrier', '25, rue Lauriston', 'Paris', '75016', 'France'),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA'),
#  (73, 'Simons bistro', 'Jytte Petersen', 'Vinbæltet 34', 'København', '1734', 'Denmark'),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK'),
#  (71, 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA')]

# %%
from sqlalchemy import desc
s = select([customers])
s = s.order_by(desc(customers.c.ContactName)).limit(20)
rp = connection.execute(s)
results =rp.fetchall()
results
# Out:
# [(91, 'Wolski', 'Zbyszek', 'ul. Filtrowa 68', 'Walla', '01-012', 'Poland'),
#  (54, 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina'),
#  (42, 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (14, 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland'),
#  (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK'),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (17, 'Drachenblut Delikatessend', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany'),
#  (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK'),
#  (64, 'Rancho grande', 'Sergio Gutiérrez', 'Av. del Libertador 900', 'Buenos Aires', '1010', 'Argentina'),
#  (20, 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria'),
#  (86, 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany'),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA'),
#  (44, 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany'),
#  (87, 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland'),
#  (39, 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany'),
#  (25, 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany'),
#  (15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA'),
#  (88, 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil')]

# %%
s = select([customers])
s = s.order_by(customers.c.ContactName,customers.c.CustomerName).limit(20)
rp = connection.execute(s)
results =rp.fetchall()
results
# Out:
# [(69, 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía, 1', 'Madrid', '28001', 'Spain'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico'),
#  (81, 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro, 414', 'São Paulo', '05634-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK'),
#  (41, "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (26, 'France restauration', 'Carine Schmitt', '54, rue Royale', 'Nantes', '44000', 'France'),
#  (46, 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela'),
#  (35, 'HILARIÓN-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela'),
#  (50, 'Maison Dewey', 'Catherine Dewey', 'Rue Joseph-Bens 532', 'Bruxelles', 'B-1180', 'Belgium'),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (40, "La corne d'abondance", 'Daniel Tonini', "67, avenue de l'Europe", 'Versailles', '78000', 'France'),
#  (22, 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal, 86', 'Madrid', '28034', 'Spain'),
#  (74, 'Spécialités du monde', 'Dominique Perrier', '25, rue Lauriston', 'Paris', '75016', 'France'),
#  (29, 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña, 23', 'Barcelona', '08022', 'Spain')]

# %%
from sqlalchemy.sql import func

# %%
s = select([customers]).where(customers.c.City == 'London')
rp = connection.execute(s)
record = rp.first()
print(record.items())
# Out:
# [('CustomerID', 4), ('CustomerName', 'Around the Horn'), ('ContactName', 'Thomas Hardy'), ('Address', '120 Hanover Sq.'), ('City', 'London'), ('PostalCode', 'WA1 1DP'), ('Country', 'UK')]

# %%
s = select([func.count(customers.c.City).label('city_name')])
s = s.where(customers.c.City == 'London')
rp = connection.execute(s)
result= rp.fetchall()

# %%
result
# Out:
# [(6,)]

# %%
rp.keys()
# Out:
# ['city_name']

# %%
s = select([customers]).where(customers.c.Country == 'Germany')
rp = connection.execute(s)
results=rp.fetchall()
results
# Out:
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (17, 'Drachenblut Delikatessend', 'Sven Ottlieb', 'Walserweg 21', 'Aachen', '52066', 'Germany'),
#  (25, 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany'),
#  (39, 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany'),
#  (44, 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany'),
#  (52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Heerstr. 22', 'Leipzig', '04179', 'Germany'),
#  (56, 'Ottilies Käseladen', 'Henriette Pfalzheim', 'Mehrheimerstr. 369', 'Köln', '50739', 'Germany'),
#  (63, 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany'),
#  (79, 'Toms Spezialitäten', 'Karin Josephs', 'Luisenstr. 48', 'Münster', '44087', 'Germany'),
#  (86, 'Die Wandernde Kuh', 'Rita Müller', 'Adenauerallee 900', 'Stuttgart', '70563', 'Germany')]

# %%
from sqlalchemy import and_, or_, not_
s = select([customers]).where(and_(
    customers.c.City == 'Berlin',
    customers.c.Country == 'Germany'
))
for row in connection.execute(s):
    print(row.CustomerName)
# Out:
# Alfreds Futterkiste

# %%
s = select([customers]).where(or_(
    customers.c.City =='Berlin',
    customers.c.City =='London',
    customers.c.Country.contains('France')
))
for row in connection.execute(s):
    print(row.CustomerName,row.Address,row.Country)
# Out:
# Alfreds Futterkiste Obere Str. 57 Germany
# Around the Horn 120 Hanover Sq. UK
# Blondel père et fils 24, place Kléber France
# Bon app' 12, rue des Bouchers France
# B's Beverages Fauntleroy Circus UK
# Consolidated Holdings Berkeley Gardens 12 Brewery UK
# Du monde entier 67, rue des Cinquante Otages France
# Eastern Connection 35 King George UK
# Folies gourmandes 184, chaussée de Tournai France
# France restauration 54, rue Royale France
# La corne d'abondance 67, avenue de l'Europe France
# La maison d'Asie 1 rue Alsace-Lorraine France
# North/South South House 300 Queensbridge UK
# Paris spécialités 265, boulevard Charonne France
# Seven Seas Imports 90 Wadhurst Rd. UK
# Spécialités du monde 25, rue Lauriston France
# Victuailles en stock 2, rue du Commerce France
# Vins et alcools Chevalier 59 rue de l'Abbaye France

# %%
s = select([customers]).where(customers.c.CustomerName.like('%Beverages%'))
rp = connection.execute(s)
for record in rp.fetchall():
    print(record.CustomerName)
# Out:
# B's Beverages

# %%
s = select([customers]).where(
    customers.c.City.in_(['Berlin','Paris','London'])
)
for row in connection.execute(s):
    print(row.CustomerName,row.Address,row.Country)
# Out:
# Alfreds Futterkiste Obere Str. 57 Germany
# Around the Horn 120 Hanover Sq. UK
# B's Beverages Fauntleroy Circus UK
# Consolidated Holdings Berkeley Gardens 12 Brewery UK
# Eastern Connection 35 King George UK
# North/South South House 300 Queensbridge UK
# Paris spécialités 265, boulevard Charonne France
# Seven Seas Imports 90 Wadhurst Rd. UK
# Spécialités du monde 25, rue Lauriston France

# %%
s = select([customers]).where(
    customers.c.CustomerID.between(12,32)
)
for row in connection.execute(s):
    print(row.CustomerName,row.Address,row.Country)
# Out:
# Cactus Comidas para llevar Cerrito 333 Argentina
# Centro comercial Moctezuma Sierras de Granada 9993 Mexico
# Chop-suey Chinese Hauptstr. 29 Switzerland
# Comércio Mineiro Av. dos Lusíadas, 23 Brazil
# Consolidated Holdings Berkeley Gardens 12 Brewery UK
# Drachenblut Delikatessend Walserweg 21 Germany
# Du monde entier 67, rue des Cinquante Otages France
# Eastern Connection 35 King George UK
# Ernst Handel Kirchgasse 6 Austria
# Familia Arquibaldo Rua Orós, 92 Brazil
# FISSA Fabrica Inter. Salchichas S.A. C/ Moralzarzal, 86 Spain
# Folies gourmandes 184, chaussée de Tournai France
# Folk och fä HB Åkergatan 24 Sweden
# Frankenversand Berliner Platz 43 Germany
# France restauration 54, rue Royale France
# Franchi S.p.A. Via Monte Bianco 34 Italy
# Furia Bacalhau e Frutos do Mar Jardim das rosas n. 32 Portugal
# Galería del gastrónomo Rambla de Cataluña, 23 Spain
# Godos Cocina Típica C/ Romero, 33 Spain
# Gourmet Lanchonetes Av. Brasil, 442 Brazil
# Great Lakes Food Market 2732 Baker Blvd. USA

# %%
s = select([customers]).where(
    customers.c.City.startswith('B')
)
for row in connection.execute(s):
    print(row.CustomerName,row.City,row.Country)
# Out:
# Alfreds Futterkiste Berlin Germany
# Cactus Comidas para llevar Buenos Aires Argentina
# Chop-suey Chinese Bern Switzerland
# Folk och fä HB Bräcke Sweden
# Galería del gastrónomo Barcelona Spain
# Königlich Essen Brandenburg Germany
# LILA-Supermercado Barquisimeto Venezuela
# Magazzini Alimentari Riuniti Bergamo Italy
# Maison Dewey Bruxelles Belgium
# Océano Atlántico Ltda. Buenos Aires Argentina
# Rancho grande Buenos Aires Argentina
# Save-a-lot Markets Boise USA
# The Cracker Box Butte USA

# %%
s = select([customers]).where(
    customers.c.City.endswith('a')
)
for row in connection.execute(s):
    print(row.CustomerName,row.City,row.Country)
# Out:
# Furia Bacalhau e Frutos do Mar Lisboa Portugal
# Galería del gastrónomo Barcelona Spain
# Godos Cocina Típica Sevilla Spain
# Lazy K Kountry Store Walla Walla USA
# LINO-Delicateses I. de Margarita Venezuela
# Princesa Isabel Vinhoss Lisboa Portugal
# Reggiani Caseifici Reggio Emilia Italy
# Wolski Walla Poland

# %%
o =select([orders])
op =connection.execute(o)
results= op.fetchall()
results
# Out:
# [(10248, 90, 5, datetime.date(1996, 7, 4), 3),
#  (10249, 81, 6, datetime.date(1996, 7, 5), 1),
#  (10250, 34, 4, datetime.date(1996, 7, 8), 2),
#  (10251, 84, 3, datetime.date(1996, 7, 8), 1),
#  (10252, 76, 4, datetime.date(1996, 7, 9), 2),
#  (10253, 34, 3, datetime.date(1996, 7, 10), 2),
#  (10254, 14, 5, datetime.date(1996, 7, 11), 2),
#  (10255, 68, 9, datetime.date(1996, 7, 12), 3),
#  (10256, 88, 3, datetime.date(1996, 7, 15), 2),
#  (10257, 35, 4, datetime.date(1996, 7, 16), 3),
#  (10258, 20, 1, datetime.date(1996, 7, 17), 1),
#  (10259, 13, 4, datetime.date(1996, 7, 18), 3),
#  (10260, 55, 4, datetime.date(1996, 7, 19), 1),
#  (10261, 61, 4, datetime.date(1996, 7, 19), 2),
#  (10262, 65, 8, datetime.date(1996, 7, 22), 3),
#  (10263, 20, 9, datetime.date(1996, 7, 23), 3),
#  (10264, 24, 6, datetime.date(1996, 7, 24), 3),
#  (10265, 7, 2, datetime.date(1996, 7, 25), 1),
#  (10266, 87, 3, datetime.date(1996, 7, 26), 3),
#  (10267, 25, 4, datetime.date(1996, 7, 29), 1),
#  (10268, 33, 8, datetime.date(1996, 7, 30), 3),
#  (10269, 89, 5, datetime.date(1996, 7, 31), 1),
#  (10270, 87, 1, datetime.date(1996, 8, 1), 1),
#  (10271, 75, 6, datetime.date(1996, 8, 1), 2),
#  (10272, 65, 6, datetime.date(1996, 8, 2), 2),
#  (10273, 63, 3, datetime.date(1996, 8, 5), 3),
#  (10274, 85, 6, datetime.date(1996, 8, 6), 1),
#  (10275, 49, 1, datetime.date(1996, 8, 7), 1),
#  (10276, 80, 8, datetime.date(1996, 8, 8), 3),
#  (10277, 52, 2, datetime.date(1996, 8, 9), 3),
#  (10278, 5, 8, datetime.date(1996, 8, 12), 2),
#  (10279, 44, 8, datetime.date(1996, 8, 13), 2),
#  (10280, 5, 2, datetime.date(1996, 8, 14), 1),
#  (10281, 69, 4, datetime.date(1996, 8, 14), 1),
#  (10282, 69, 4, datetime.date(1996, 8, 15), 1),
#  (10283, 46, 3, datetime.date(1996, 8, 16), 3),
#  (10284, 44, 4, datetime.date(1996, 8, 19), 1),
#  (10285, 63, 1, datetime.date(1996, 8, 20), 2),
#  (10286, 63, 8, datetime.date(1996, 8, 21), 3),
#  (10287, 67, 8, datetime.date(1996, 8, 22), 3),
#  (10288, 66, 4, datetime.date(1996, 8, 23), 1),
#  (10289, 11, 7, datetime.date(1996, 8, 26), 3),
#  (10290, 15, 8, datetime.date(1996, 8, 27), 1),
#  (10291, 61, 6, datetime.date(1996, 8, 27), 2),
#  (10292, 81, 1, datetime.date(1996, 8, 28), 2),
#  (10293, 80, 1, datetime.date(1996, 8, 29), 3),
#  (10294, 65, 4, datetime.date(1996, 8, 30), 2),
#  (10295, 85, 2, datetime.date(1996, 9, 2), 2),
#  (10296, 46, 6, datetime.date(1996, 9, 3), 1),
#  (10297, 7, 5, datetime.date(1996, 9, 4), 2),
#  (10298, 37, 6, datetime.date(1996, 9, 5), 2),
#  (10299, 67, 4, datetime.date(1996, 9, 6), 2),
#  (10300, 49, 2, datetime.date(1996, 9, 9), 2),
#  (10301, 86, 8, datetime.date(1996, 9, 9), 2),
#  (10302, 76, 4, datetime.date(1996, 9, 10), 2),
#  (10303, 30, 7, datetime.date(1996, 9, 11), 2),
#  (10304, 80, 1, datetime.date(1996, 9, 12), 2),
#  (10305, 55, 8, datetime.date(1996, 9, 13), 3),
#  (10306, 69, 1, datetime.date(1996, 9, 16), 3),
#  (10307, 48, 2, datetime.date(1996, 9, 17), 2),
#  (10308, 2, 7, datetime.date(1996, 9, 18), 3),
#  (10309, 37, 3, datetime.date(1996, 9, 19), 1),
#  (10310, 77, 8, datetime.date(1996, 9, 20), 2),
#  (10311, 18, 1, datetime.date(1996, 9, 20), 3),
#  (10312, 86, 2, datetime.date(1996, 9, 23), 2),
#  (10313, 63, 2, datetime.date(1996, 9, 24), 2),
#  (10314, 65, 1, datetime.date(1996, 9, 25), 2),
#  (10315, 38, 4, datetime.date(1996, 9, 26), 2),
#  (10316, 65, 1, datetime.date(1996, 9, 27), 3),
#  (10317, 48, 6, datetime.date(1996, 9, 30), 1),
#  (10318, 38, 8, datetime.date(1996, 10, 1), 2),
#  (10319, 80, 7, datetime.date(1996, 10, 2), 3),
#  (10320, 87, 5, datetime.date(1996, 10, 3), 3),
#  (10321, 38, 3, datetime.date(1996, 10, 3), 2),
#  (10322, 58, 7, datetime.date(1996, 10, 4), 3),
#  (10323, 39, 4, datetime.date(1996, 10, 7), 1),
#  (10324, 71, 9, datetime.date(1996, 10, 8), 1),
#  (10325, 39, 1, datetime.date(1996, 10, 9), 3),
#  (10326, 8, 4, datetime.date(1996, 10, 10), 2),
#  (10327, 24, 2, datetime.date(1996, 10, 11), 1),
#  (10328, 28, 4, datetime.date(1996, 10, 14), 3),
#  (10329, 75, 4, datetime.date(1996, 10, 15), 2),
#  (10330, 46, 3, datetime.date(1996, 10, 16), 1),
#  (10331, 9, 9, datetime.date(1996, 10, 16), 1),
#  (10332, 51, 3, datetime.date(1996, 10, 17), 2),
#  (10333, 87, 5, datetime.date(1996, 10, 18), 3),
#  (10334, 84, 8, datetime.date(1996, 10, 21), 2),
#  (10335, 37, 7, datetime.date(1996, 10, 22), 2),
#  (10336, 60, 7, datetime.date(1996, 10, 23), 2),
#  (10337, 25, 4, datetime.date(1996, 10, 24), 3),
#  (10338, 55, 4, datetime.date(1996, 10, 25), 3),
#  (10339, 51, 2, datetime.date(1996, 10, 28), 2),
#  (10340, 9, 1, datetime.date(1996, 10, 29), 3),
#  (10341, 73, 7, datetime.date(1996, 10, 29), 3),
#  (10342, 25, 4, datetime.date(1996, 10, 30), 2),
#  (10343, 44, 4, datetime.date(1996, 10, 31), 1),
#  (10344, 89, 4, datetime.date(1996, 11, 1), 2),
#  (10345, 63, 2, datetime.date(1996, 11, 4), 2),
#  (10346, 65, 3, datetime.date(1996, 11, 5), 3),
#  (10347, 21, 4, datetime.date(1996, 11, 6), 3),
#  (10348, 86, 4, datetime.date(1996, 11, 7), 2),
#  (10349, 75, 7, datetime.date(1996, 11, 8), 1),
#  (10350, 41, 6, datetime.date(1996, 11, 11), 2),
#  (10351, 20, 1, datetime.date(1996, 11, 11), 1),
#  (10352, 28, 3, datetime.date(1996, 11, 12), 3),
#  (10353, 59, 7, datetime.date(1996, 11, 13), 3),
#  (10354, 58, 8, datetime.date(1996, 11, 14), 3),
#  (10355, 4, 6, datetime.date(1996, 11, 15), 1),
#  (10356, 86, 6, datetime.date(1996, 11, 18), 2),
#  (10357, 46, 1, datetime.date(1996, 11, 19), 3),
#  (10358, 41, 5, datetime.date(1996, 11, 20), 1),
#  (10359, 72, 5, datetime.date(1996, 11, 21), 3),
#  (10360, 7, 4, datetime.date(1996, 11, 22), 3),
#  (10361, 63, 1, datetime.date(1996, 11, 22), 2),
#  (10362, 9, 3, datetime.date(1996, 11, 25), 1),
#  (10363, 17, 4, datetime.date(1996, 11, 26), 3),
#  (10364, 19, 1, datetime.date(1996, 11, 26), 1),
#  (10365, 3, 3, datetime.date(1996, 11, 27), 2),
#  (10366, 29, 8, datetime.date(1996, 11, 28), 2),
#  (10367, 83, 7, datetime.date(1996, 11, 28), 3),
#  (10368, 20, 2, datetime.date(1996, 11, 29), 2),
#  (10369, 75, 8, datetime.date(1996, 12, 2), 2),
#  (10370, 14, 6, datetime.date(1996, 12, 3), 2),
#  (10371, 41, 1, datetime.date(1996, 12, 3), 1),
#  (10372, 62, 5, datetime.date(1996, 12, 4), 2),
#  (10373, 37, 4, datetime.date(1996, 12, 5), 3),
#  (10374, 91, 1, datetime.date(1996, 12, 5), 3),
#  (10375, 36, 3, datetime.date(1996, 12, 6), 2),
#  (10376, 51, 1, datetime.date(1996, 12, 9), 2),
#  (10377, 72, 1, datetime.date(1996, 12, 9), 3),
#  (10378, 24, 5, datetime.date(1996, 12, 10), 3),
#  (10379, 61, 2, datetime.date(1996, 12, 11), 1),
#  (10380, 37, 8, datetime.date(1996, 12, 12), 3),
#  (10381, 46, 3, datetime.date(1996, 12, 12), 3),
#  (10382, 20, 4, datetime.date(1996, 12, 13), 1),
#  (10383, 4, 8, datetime.date(1996, 12, 16), 3),
#  (10384, 5, 3, datetime.date(1996, 12, 16), 3),
#  (10385, 75, 1, datetime.date(1996, 12, 17), 2),
#  (10386, 21, 9, datetime.date(1996, 12, 18), 3),
#  (10387, 70, 1, datetime.date(1996, 12, 18), 2),
#  (10388, 72, 2, datetime.date(1996, 12, 19), 1),
#  (10389, 10, 4, datetime.date(1996, 12, 20), 2),
#  (10390, 20, 6, datetime.date(1996, 12, 23), 1),
#  (10391, 17, 3, datetime.date(1996, 12, 23), 3),
#  (10392, 59, 2, datetime.date(1996, 12, 24), 3),
#  (10393, 71, 1, datetime.date(1996, 12, 25), 3),
#  (10394, 36, 1, datetime.date(1996, 12, 25), 3),
#  (10395, 35, 6, datetime.date(1996, 12, 26), 1),
#  (10396, 25, 1, datetime.date(1996, 12, 27), 3),
#  (10397, 60, 5, datetime.date(1996, 12, 27), 1),
#  (10398, 71, 2, datetime.date(1996, 12, 30), 3),
#  (10399, 83, 8, datetime.date(1996, 12, 31), 3),
#  (10400, 19, 1, datetime.date(1997, 1, 1), 3),
#  (10401, 65, 1, datetime.date(1997, 1, 1), 1),
#  (10402, 20, 8, datetime.date(1997, 1, 2), 2),
#  (10403, 20, 4, datetime.date(1997, 1, 3), 3),
#  (10404, 49, 2, datetime.date(1997, 1, 3), 1),
#  (10405, 47, 1, datetime.date(1997, 1, 6), 1),
#  (10406, 62, 7, datetime.date(1997, 1, 7), 1),
#  (10407, 56, 2, datetime.date(1997, 1, 7), 2),
#  (10408, 23, 8, datetime.date(1997, 1, 8), 1),
#  (10409, 54, 3, datetime.date(1997, 1, 9), 1),
#  (10410, 10, 3, datetime.date(1997, 1, 10), 3),
#  (10411, 10, 9, datetime.date(1997, 1, 10), 3),
#  (10412, 87, 8, datetime.date(1997, 1, 13), 2),
#  (10413, 41, 3, datetime.date(1997, 1, 14), 2),
#  (10414, 21, 2, datetime.date(1997, 1, 14), 3),
#  (10415, 36, 3, datetime.date(1997, 1, 15), 1),
#  (10416, 87, 8, datetime.date(1997, 1, 16), 3),
#  (10417, 73, 4, datetime.date(1997, 1, 16), 3),
#  (10418, 63, 4, datetime.date(1997, 1, 17), 1),
#  (10419, 68, 4, datetime.date(1997, 1, 20), 2),
#  (10420, 88, 3, datetime.date(1997, 1, 21), 1),
#  (10421, 61, 8, datetime.date(1997, 1, 21), 1),
#  (10422, 27, 2, datetime.date(1997, 1, 22), 1),
#  (10423, 31, 6, datetime.date(1997, 1, 23), 3),
#  (10424, 51, 7, datetime.date(1997, 1, 23), 2),
#  (10425, 41, 6, datetime.date(1997, 1, 24), 2),
#  (10426, 29, 4, datetime.date(1997, 1, 27), 1),
#  (10427, 59, 4, datetime.date(1997, 1, 27), 2),
#  (10428, 66, 7, datetime.date(1997, 1, 28), 1),
#  (10429, 37, 3, datetime.date(1997, 1, 29), 2),
#  (10430, 20, 4, datetime.date(1997, 1, 30), 1),
#  (10431, 10, 4, datetime.date(1997, 1, 30), 2),
#  (10432, 75, 3, datetime.date(1997, 1, 31), 2),
#  (10433, 60, 3, datetime.date(1997, 2, 3), 3),
#  (10434, 24, 3, datetime.date(1997, 2, 3), 2),
#  (10435, 16, 8, datetime.date(1997, 2, 4), 2),
#  (10436, 7, 3, datetime.date(1997, 2, 5), 2),
#  (10437, 87, 8, datetime.date(1997, 2, 5), 1),
#  (10438, 79, 3, datetime.date(1997, 2, 6), 2),
#  (10439, 51, 6, datetime.date(1997, 2, 7), 3),
#  (10440, 71, 4, datetime.date(1997, 2, 10), 2),
#  (10441, 55, 3, datetime.date(1997, 2, 10), 2),
#  (10442, 20, 3, datetime.date(1997, 2, 11), 2),
#  (10443, 66, 8, datetime.date(1997, 2, 12), 1)]

# %%
op.keys()
# Out:
# ['OrderID', 'CustomerID', 'EmployeeID', 'OrderDate', 'ShipperID']

# %%
s = select([customers,orders.c.ShipperID]).where(and_
     (orders.c.ShipperID == 1,
     customers.c.CustomerID == orders.c.CustomerID))

str(s)
# Out:
# 'SELECT customers."CustomerID", customers."CustomerName", customers."ContactName", customers."Address", customers."City", customers."PostalCode", customers."Country", orders."ShipperID" \nFROM customers, orders \nWHERE orders."ShipperID" = :ShipperID_1 AND customers."CustomerID" = orders."CustomerID"'

# %%
rp = connection.execute(s)
results =rp.fetchall()
results
# Out:
# [(81, 'Tradição Hipermercados', 'Anabela Domingues', 'Av. Inês de Castro, 414', 'São Paulo', '05634-030', 'Brazil', 1),
#  (84, 'Victuailles en stock', 'Mary Saveley', '2, rue du Commerce', 'Lyon', '69004', 'France', 1),
#  (20, 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria', 1),
#  (55, 'Old World Delicatessen', 'Rene Phillips', '2743 Bering St.', 'Anchorage', '99508', 'USA', 1),
#  (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France', 1),
#  (25, 'Frankenversand', 'Peter Franken', 'Berliner Platz 43', 'München', '80805', 'Germany', 1),
#  (89, 'White Clover Markets', 'Karl Jablonski', '305 - 14th Ave. S. Suite 3B', 'Seattle', '98128', 'USA', 1),
#  (87, 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland', 1),
#  (85, 'Vins et alcools Chevalier', 'Paul Henriot', "59 rue de l'Abbaye", 'Reims', '51100', 'France', 1),
#  (49, 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy', 1),
#  (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden', 1),
#  (69, 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía, 1', 'Madrid', '28001', 'Spain', 1),
#  (69, 'Romero y tomillo', 'Alejandra Camino', 'Gran Vía, 1', 'Madrid', '28001', 'Spain', 1),
#  (44, 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany', 1),
#  (66, 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy', 1),
#  (15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil', 1),
#  (46, 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela', 1),
#  (37, 'Hungry Owl All-Night Grocers', 'Patricia McKenna', '8 Johnstown Road', 'Cork', None, 'Ireland', 1),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA', 1),
#  (39, 'Königlich Essen', 'Philip Cramer', 'Maubelstr. 90', 'Brandenburg', '14776', 'Germany', 1),
#  (71, 'Save-a-lot Markets', 'Jose Pavarotti', '187 Suffolk Ln.', 'Boise', '83720', 'USA', 1),
#  (24, 'Folk och fä HB', 'Maria Larsson', 'Åkergatan 24', 'Bräcke', 'S-844 67', 'Sweden', 1),
#  (46, 'LILA-Supermercado', 'Carlos González', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'Barquisimeto', '3508', 'Venezuela', 1),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France', 1),
#  (44, 'Lehmanns Marktstand', 'Renate Messner', 'Magazinweg 7', 'Frankfurt a.M.', '60528', 'Germany', 1),
#  (75, 'Split Rail Beer & Ale', 'Art Braunschweiger', 'P.O. Box 555', 'Lander', '82520', 'USA', 1),
#  (20, 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria', 1),
#  (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK', 1),
#  (41, "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France', 1),
#  (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France', 1),
#  (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK', 1),
#  (41, "La maison d'Asie", 'Annette Roulet', '1 rue Alsace-Lorraine', 'Toulouse', '31000', 'France', 1),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil', 1),
#  (20, 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria', 1),
#  (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK', 1),
#  (20, 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria', 1),
#  (35, 'HILARIÓN-Abastos', 'Carlos Hernández', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'San Cristóbal', '5022', 'Venezuela', 1),
#  (60, 'Princesa Isabel Vinhoss', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal', 1),
#  (65, 'Rattlesnake Canyon Grocery', 'Paula Wilson', '2817 Milton Dr.', 'Albuquerque', '87110', 'USA', 1),
#  (49, 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Via Ludovico il Moro 22', 'Bergamo', '24100', 'Italy', 1),
#  (47, 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela', 1),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil', 1),
#  (23, 'Folies gourmandes', 'Martine Rancé', '184, chaussée de Tournai', 'Lille', '59000', 'France', 1),
#  (54, 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina', 1),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA', 1),
#  (63, 'QUICK-Stop', 'Horst Kloss', 'Taucherstraße 10', 'Cunewalde', '01307', 'Germany', 1),
#  (88, 'Wellington Importadora', 'Paula Parente', 'Rua do Mercado, 12', 'Resende', '08737-363', 'Brazil', 1),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil', 1),
#  (27, 'Franchi S.p.A.', 'Paolo Accorti', 'Via Monte Bianco 34', 'Torino', '10100', 'Italy', 1),
#  (29, 'Galería del gastrónomo', 'Eduardo Saavedra', 'Rambla de Cataluña, 23', 'Barcelona', '08022', 'Spain', 1),
#  (66, 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy', 1),
#  (20, 'Ernst Handel', 'Roland Mendel', 'Kirchgasse 6', 'Graz', '8010', 'Austria', 1),
#  (87, 'Wartian Herkku', 'Pirkko Koskitalo', 'Torikatu 38', 'Oulu', '90110', 'Finland', 1),
#  (66, 'Reggiani Caseifici', 'Maurizio Moroni', 'Strada Provinciale 124', 'Reggio Emilia', '42100', 'Italy', 1)]

# %%
df_category.head()
# Out:
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
#
#                                          Description
# 0        Soft drinks, coffees, teas, beers, and ales
# 1  Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads
# 3                                            Cheeses
# 4                Breads, crackers, pasta, and cereal

# %%
df_employee.head()
# Out:
#    EmployeeID   LastName FirstName   BirthDate       Photo  \
# 0           1    Davolio     Nancy  1968-12-08  EmpID1.pic
# 1           2     Fuller    Andrew  1952-02-19  EmpID2.pic
# 2           3  Leverling     Janet  1963-08-30  EmpID3.pic
# 3           4    Peacock  Margaret  1958-09-19  EmpID4.pic
# 4           5   Buchanan    Steven  1955-03-04  EmpID5.pic
#
#                                                Notes
# 0  Education includes a BA in psychology from Col...
# 1  Andrew received his BTS commercial and a Ph.D....
# 2  Janet has a BS degree in chemistry from Boston...
# 3  Margaret holds a BA in English literature from...
# 4  Steven Buchanan graduated from St. Andrews Uni...

# %%
df_order_detail.head()
# Out:
#    OrderDetailID  OrderID  ProductID  Quantity
# 0              1    10248         11        12
# 1              2    10248         42        10
# 2              3    10248         72         5
# 3              4    10249         14         9
# 4              5    10249         51        40

# %%
df_customers.head()
# Out:
#    CustomerID                        CustomerName         ContactName  \
# 0           1                 Alfreds Futterkiste        Maria Anders
# 1           2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2           3             Antonio Moreno Taquería      Antonio Moreno
# 3           4                     Around the Horn        Thomas Hardy
# 4           5                  Berglunds snabbköp  Christina Berglund
#
#                          Address         City PostalCode  Country
# 0                  Obere Str. 57       Berlin      12209  Germany
# 1  Avda. de la Constitución 2222  México D.F.      05021   Mexico
# 2                 Mataderos 2312  México D.F.      05023   Mexico
# 3                120 Hanover Sq.       London    WA1 1DP       UK
# 4                 Berguvsvägen 8        Luleå   S-958 22   Sweden

# %%
df_orders.head()
# Out:
#    OrderID  CustomerID  EmployeeID   OrderDate  ShipperID
# 0    10248          90           5  1996-07-04          3
# 1    10249          81           6  1996-07-05          1
# 2    10250          34           4  1996-07-08          2
# 3    10251          84           3  1996-07-08          1
# 4    10252          76           4  1996-07-09          2

# %%
df_product.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                         Chais           1           1
# 1          2                         Chang           1           1
# 2          3                 Aniseed Syrup           1           2
# 3          4  Chef Anton's Cajun Seasoning           2           2
# 4          5        Chef Anton's Gumbo Mix           2           2
#
#                   Unit  Price
# 0   10 boxes x 20 bags  18.00
# 1   24 - 12 oz bottles  19.00
# 2  12 - 550 ml bottles  10.00
# 3       48 - 6 oz jars  22.00
# 4             36 boxes  21.35

# %%
df_shipper
# Out:
#    ShipperID       ShipperName           Phone
# 0          1    Speedy Express  (503) 555-9831
# 1          2    United Package  (503) 555-3199
# 2          3  Federal Shipping  (503) 555-9931

# %%
df_supplier.head()
# Out:
#    SupplierID                        SupplierName                 ContactName  \
# 0           1                       Exotic Liquid            Charlotte Cooper
# 1           2          New Orleans Cajun Delights               Shelley Burke
# 2           3           Grandma Kelly's Homestead               Regina Murphy
# 3           4                       Tokyo Traders                Yoshi Nagase
# 4           5  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
#
#                      Address         City PostalCode Country           Phone
# 0             49 Gilbert St.      Londona    EC1 4SD      UK  (171) 555-2222
# 1             P.O. Box 78934  New Orleans      70117     USA  (100) 555-4822
# 2             707 Oxford Rd.    Ann Arbor      48104     USA  (313) 555-5735
# 3  9-8 Sekimai Musashino-shi        Tokyo        100   Japan  (03) 3555-5011
# 4          Calle del Rosal 4       Oviedo      33007   Spain  (98) 598 76 54

# %%
columns = [customers.c.CustomerName, func.count(orders.c.OrderID),func.count(order_detail.c.ProductID)]
all_orders = select(columns)
all_orders = all_orders.select_from(customers.outerjoin(orders).outerjoin(order_detail))
all_orders = all_orders.group_by(customers.c.CustomerName)
result = connection.execute(all_orders).fetchall()
for row in result:
    print(row)
# Out:
# ('Alfreds Futterkiste', 0, 0)
# ('Ana Trujillo Emparedados y helados', 2, 2)
# ('Antonio Moreno Taquería', 1, 1)
# ('Around the Horn', 5, 5)
# ("B's Beverages", 2, 2)
# ('Berglunds snabbköp', 9, 9)
# ('Blauer See Delikatessen', 0, 0)
# ('Blondel père et fils', 13, 13)
# ("Bon app'", 7, 7)
# ('Bottom-Dollar Marketse', 12, 12)
# ('Bólido Comidas preparadas', 3, 3)
# ('Cactus Comidas para llevar', 0, 0)
# ('Centro comercial Moctezuma', 2, 2)
# ('Chop-suey Chinese', 6, 6)
# ('Comércio Mineiro', 4, 4)
# ('Consolidated Holdings', 3, 3)
# ('Die Wandernde Kuh', 11, 11)
# ('Drachenblut Delikatessend', 4, 4)
# ('Du monde entier', 2, 2)
# ('Eastern Connection', 5, 5)
# ('Ernst Handel', 35, 35)
# ('FISSA Fabrica Inter. Salchichas S.A.', 0, 0)
# ('Familia Arquibaldo', 8, 8)
# ('Folies gourmandes', 3, 3)
# ('Folk och fä HB', 9, 9)
# ('France restauration', 0, 0)
# ('Franchi S.p.A.', 1, 1)
# ('Frankenversand', 15, 15)
# ('Furia Bacalhau e Frutos do Mar', 5, 5)
# ('GROSELLA-Restaurante', 2, 2)
# ('Galería del gastrónomo', 4, 4)
# ('Godos Cocina Típica', 3, 3)
# ('Gourmet Lanchonetes', 2, 2)
# ('Great Lakes Food Market', 0, 0)
# ('HILARIÓN-Abastos', 6, 6)
# ('Hanari Carnes', 6, 6)
# ('Hungry Coyote Import Store', 6, 6)
# ('Hungry Owl All-Night Grocers', 21, 21)
# ('Island Trading', 5, 5)
# ('Königlich Essen', 8, 8)
# ('LILA-Supermercado', 13, 13)
# ('LINO-Delicateses', 1, 1)
# ("La corne d'abondance", 0, 0)
# ("La maison d'Asie", 11, 11)
# ('Laughing Bacchus Wine Cellars', 0, 0)
# ('Lazy K Kountry Store', 0, 0)
# ('Lehmanns Marktstand', 8, 8)
# ("Let's Stop N Shop", 0, 0)
# ('Lonesome Pine Restaurant', 3, 3)
# ('Magazzini Alimentari Riuniti', 7, 7)
# ('Maison Dewey', 0, 0)
# ('Morgenstern Gesundkost', 2, 2)
# ('Mère Paillarde', 14, 14)
# ('North/South', 0, 0)
# ('Océano Atlántico Ltda.', 2, 2)
# ('Old World Delicatessen', 10, 10)
# ('Ottilies Käseladen', 3, 3)
# ('Paris spécialités', 0, 0)
# ('Pericles Comidas clásicas', 3, 3)
# ('Piccolo und mehr', 4, 4)
# ('Princesa Isabel Vinhoss', 4, 4)
# ('QUICK-Stop', 20, 20)
# ('Que Delícia', 12, 12)
# ('Queen Cozinha', 9, 9)
# ('Rancho grande', 0, 0)
# ('Rattlesnake Canyon Grocery', 22, 22)
# ('Reggiani Caseifici', 5, 5)
# ('Ricardo Adocicados', 5, 5)
# ('Richter Supermarkt', 6, 6)
# ('Romero y tomillo', 8, 8)
# ('Santé Gourmet', 4, 4)
# ('Save-a-lot Markets', 16, 16)
# ('Seven Seas Imports', 8, 8)
# ('Simons bistro', 6, 6)
# ('Split Rail Beer & Ale', 13, 13)
# ('Spécialités du monde', 0, 0)
# ('Suprêmes délices', 6, 6)
# ('The Big Cheese', 2, 2)
# ('The Cracker Box', 0, 0)
# ('Toms Spezialitäten', 3, 3)
# ('Tortuga Restaurante', 12, 12)
# ('Tradição Hipermercados', 3, 3)
# ("Trail's Head Gourmet Provisioners", 0, 0)
# ('Vaffeljernet', 8, 8)
# ('Victuailles en stock', 5, 5)
# ('Vins et alcools Chevalier', 3, 3)
# ('Wartian Herkku', 12, 12)
# ('Wellington Importadora', 6, 6)
# ('White Clover Markets', 4, 4)
# ('Wilman Kala', 3, 3)
# ('Wolski', 2, 2)

# %% [markdown]
# Use outerjoin() for queries involving some sort of count

# %%
columns = [customers.c.CustomerName, orders.c.OrderID,order_detail.c.ProductID,product.c.ProductName,shipper.c.ShipperName,supplier.c.SupplierName]
all_orders = select(columns)
all_orders = all_orders.select_from(customers.outerjoin(orders).outerjoin(shipper).outerjoin(order_detail).outerjoin(product).outerjoin(supplier))
all_orders = all_orders.order_by(customers.c.CustomerName)
result = connection.execute(all_orders).fetchall()
for row in result:
    print(row)
# Out:
# ('Alfreds Futterkiste', None, None, None, None, None)
# ('Ana Trujillo Emparedados y helados', 10308, 69, 'Gudbrandsdalsost', 'Federal Shipping', 'Norske Meierier')
# ('Ana Trujillo Emparedados y helados', 10308, 70, 'Outback Lager', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Antonio Moreno Taquería', 10365, 11, 'Queso Cabrales', 'United Package', "Cooperativa de Quesos 'Las Cabras'")
# ('Around the Horn', 10355, 24, 'Guaraná Fantástica', 'Speedy Express', 'Refrescos Americanas LTDA')
# ('Around the Horn', 10355, 57, 'Ravioli Angelo', 'Speedy Express', 'Pasta Buttini s.r.l.')
# ('Around the Horn', 10383, 13, 'Konbu', 'Federal Shipping', "Mayumi's")
# ('Around the Horn', 10383, 50, 'Valkoinen suklaa', 'Federal Shipping', 'Karkki Oy')
# ('Around the Horn', 10383, 56, 'Gnocchi di nonna Alice', 'Federal Shipping', 'Pasta Buttini s.r.l.')
# ("B's Beverages", 10289, 3, 'Aniseed Syrup', 'Federal Shipping', 'Exotic Liquid')
# ("B's Beverages", 10289, 64, 'Wimmers gute Semmelknödel', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Berglunds snabbköp', 10280, 24, 'Guaraná Fantástica', 'Speedy Express', 'Refrescos Americanas LTDA')
# ('Berglunds snabbköp', 10280, 55, 'Pâté chinois', 'Speedy Express', 'Ma Maison')
# ('Berglunds snabbköp', 10280, 75, 'Rhönbräu Klosterbier', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Berglunds snabbköp', 10278, 44, 'Gula Malacca', 'United Package', 'Leka Trading')
# ('Berglunds snabbköp', 10278, 59, 'Raclette Courdavault', 'United Package', 'Gai pâturage')
# ('Berglunds snabbköp', 10278, 63, 'Vegie-spread', 'United Package', 'Pavlova, Ltd.')
# ('Berglunds snabbköp', 10278, 73, 'Röd Kaviar', 'United Package', 'Svensk Sjöföda AB')
# ('Berglunds snabbköp', 10384, 20, "Sir Rodney's Marmalade", 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('Berglunds snabbköp', 10384, 60, 'Camembert Pierrot', 'Federal Shipping', 'Gai pâturage')
# ('Blauer See Delikatessen', None, None, None, None, None)
# ('Blondel père et fils', 10265, 17, 'Alice Mutton', 'Speedy Express', 'Pavlova, Ltd.')
# ('Blondel père et fils', 10265, 70, 'Outback Lager', 'Speedy Express', 'Pavlova, Ltd.')
# ('Blondel père et fils', 10297, 39, 'Chartreuse verte', 'United Package', 'Aux joyeux ecclésiastiques')
# ('Blondel père et fils', 10297, 72, 'Mozzarella di Giovanni', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Blondel père et fils', 10436, 46, 'Spegesild', 'United Package', 'Lyngbysild')
# ('Blondel père et fils', 10436, 56, 'Gnocchi di nonna Alice', 'United Package', 'Pasta Buttini s.r.l.')
# ('Blondel père et fils', 10436, 64, 'Wimmers gute Semmelknödel', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Blondel père et fils', 10436, 75, 'Rhönbräu Klosterbier', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Blondel père et fils', 10360, 28, 'Rössle Sauerkraut', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Blondel père et fils', 10360, 29, 'Thüringer Rostbratwurst', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Blondel père et fils', 10360, 38, 'Côte de Blaye', 'Federal Shipping', 'Aux joyeux ecclésiastiques')
# ('Blondel père et fils', 10360, 49, 'Maxilaku', 'Federal Shipping', 'Karkki Oy')
# ('Blondel père et fils', 10360, 54, 'Tourtière', 'Federal Shipping', 'Ma Maison')
# ("Bon app'", 10331, 54, 'Tourtière', 'Speedy Express', 'Ma Maison')
# ("Bon app'", 10362, 25, 'NuNuCa Nuß-Nougat-Creme', 'Speedy Express', 'Heli Süßwaren GmbH & Co. KG')
# ("Bon app'", 10362, 51, 'Manjimup Dried Apples', 'Speedy Express', "G'day, Mate")
# ("Bon app'", 10362, 54, 'Tourtière', 'Speedy Express', 'Ma Maison')
# ("Bon app'", 10340, 18, 'Carnarvon Tigers', 'Federal Shipping', 'Pavlova, Ltd.')
# ("Bon app'", 10340, 41, "Jack's New England Clam Chowder", 'Federal Shipping', 'New England Seafood Cannery')
# ("Bon app'", 10340, 43, 'Ipoh Coffee', 'Federal Shipping', 'Leka Trading')
# ('Bottom-Dollar Marketse', 10389, 10, 'Ikura', 'United Package', 'Tokyo Traders')
# ('Bottom-Dollar Marketse', 10389, 55, 'Pâté chinois', 'United Package', 'Ma Maison')
# ('Bottom-Dollar Marketse', 10389, 62, 'Tarte au sucre', 'United Package', "Forêts d'érables")
# ('Bottom-Dollar Marketse', 10389, 70, 'Outback Lager', 'United Package', 'Pavlova, Ltd.')
# ('Bottom-Dollar Marketse', 10431, 17, 'Alice Mutton', 'United Package', 'Pavlova, Ltd.')
# ('Bottom-Dollar Marketse', 10431, 40, 'Boston Crab Meat', 'United Package', 'New England Seafood Cannery')
# ('Bottom-Dollar Marketse', 10431, 47, 'Zaanse koeken', 'United Package', 'Zaanse Snoepfabriek')
# ('Bottom-Dollar Marketse', 10410, 33, 'Geitost', 'Federal Shipping', 'Norske Meierier')
# ('Bottom-Dollar Marketse', 10410, 59, 'Raclette Courdavault', 'Federal Shipping', 'Gai pâturage')
# ('Bottom-Dollar Marketse', 10411, 41, "Jack's New England Clam Chowder", 'Federal Shipping', 'New England Seafood Cannery')
# ('Bottom-Dollar Marketse', 10411, 44, 'Gula Malacca', 'Federal Shipping', 'Leka Trading')
# ('Bottom-Dollar Marketse', 10411, 59, 'Raclette Courdavault', 'Federal Shipping', 'Gai pâturage')
# ('Bólido Comidas preparadas', 10326, 4, "Chef Anton's Cajun Seasoning", 'United Package', 'New Orleans Cajun Delights')
# ('Bólido Comidas preparadas', 10326, 57, 'Ravioli Angelo', 'United Package', 'Pasta Buttini s.r.l.')
# ('Bólido Comidas preparadas', 10326, 75, 'Rhönbräu Klosterbier', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Cactus Comidas para llevar', None, None, None, None, None)
# ('Centro comercial Moctezuma', 10259, 21, "Sir Rodney's Scones", 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('Centro comercial Moctezuma', 10259, 37, 'Gravad lax', 'Federal Shipping', 'Svensk Sjöföda AB')
# ('Chop-suey Chinese', 10254, 24, 'Guaraná Fantástica', 'United Package', 'Refrescos Americanas LTDA')
# ('Chop-suey Chinese', 10254, 55, 'Pâté chinois', 'United Package', 'Ma Maison')
# ('Chop-suey Chinese', 10254, 74, 'Longlife Tofu', 'United Package', 'Tokyo Traders')
# ('Chop-suey Chinese', 10370, 1, 'Chais', 'United Package', 'Exotic Liquid')
# ('Chop-suey Chinese', 10370, 64, 'Wimmers gute Semmelknödel', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Chop-suey Chinese', 10370, 74, 'Longlife Tofu', 'United Package', 'Tokyo Traders')
# ('Comércio Mineiro', 10290, 5, "Chef Anton's Gumbo Mix", 'Speedy Express', 'New Orleans Cajun Delights')
# ('Comércio Mineiro', 10290, 29, 'Thüringer Rostbratwurst', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Comércio Mineiro', 10290, 49, 'Maxilaku', 'Speedy Express', 'Karkki Oy')
# ('Comércio Mineiro', 10290, 77, 'Original Frankfurter grüne Soße', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Consolidated Holdings', 10435, 2, 'Chang', 'United Package', 'Exotic Liquid')
# ('Consolidated Holdings', 10435, 22, "Gustaf's Knäckebröd", 'United Package', 'PB Knäckebröd AB')
# ('Consolidated Holdings', 10435, 72, 'Mozzarella di Giovanni', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Die Wandernde Kuh', 10301, 40, 'Boston Crab Meat', 'United Package', 'New England Seafood Cannery')
# ('Die Wandernde Kuh', 10301, 56, 'Gnocchi di nonna Alice', 'United Package', 'Pasta Buttini s.r.l.')
# ('Die Wandernde Kuh', 10312, 28, 'Rössle Sauerkraut', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Die Wandernde Kuh', 10312, 43, 'Ipoh Coffee', 'United Package', 'Leka Trading')
# ('Die Wandernde Kuh', 10312, 53, 'Perth Pasties', 'United Package', "G'day, Mate")
# ('Die Wandernde Kuh', 10312, 75, 'Rhönbräu Klosterbier', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Die Wandernde Kuh', 10348, 1, 'Chais', 'United Package', 'Exotic Liquid')
# ('Die Wandernde Kuh', 10348, 23, 'Tunnbröd', 'United Package', 'PB Knäckebröd AB')
# ('Die Wandernde Kuh', 10356, 31, 'Gorgonzola Telino', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Die Wandernde Kuh', 10356, 55, 'Pâté chinois', 'United Package', 'Ma Maison')
# ('Die Wandernde Kuh', 10356, 69, 'Gudbrandsdalsost', 'United Package', 'Norske Meierier')
# ('Drachenblut Delikatessend', 10363, 31, 'Gorgonzola Telino', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Drachenblut Delikatessend', 10363, 75, 'Rhönbräu Klosterbier', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Drachenblut Delikatessend', 10363, 76, 'Lakkalikööri', 'Federal Shipping', 'Karkki Oy')
# ('Drachenblut Delikatessend', 10391, 13, 'Konbu', 'Federal Shipping', "Mayumi's")
# ('Du monde entier', 10311, 42, 'Singaporean Hokkien Fried Mee', 'Federal Shipping', 'Leka Trading')
# ('Du monde entier', 10311, 69, 'Gudbrandsdalsost', 'Federal Shipping', 'Norske Meierier')
# ('Eastern Connection', 10364, 69, 'Gudbrandsdalsost', 'Speedy Express', 'Norske Meierier')
# ('Eastern Connection', 10364, 71, 'Fløtemysost', 'Speedy Express', 'Norske Meierier')
# ('Eastern Connection', 10400, 29, 'Thüringer Rostbratwurst', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Eastern Connection', 10400, 35, 'Steeleye Stout', 'Federal Shipping', 'Bigfoot Breweries')
# ('Eastern Connection', 10400, 49, 'Maxilaku', 'Federal Shipping', 'Karkki Oy')
# ('Ernst Handel', 10258, 2, 'Chang', 'Speedy Express', 'Exotic Liquid')
# ('Ernst Handel', 10258, 5, "Chef Anton's Gumbo Mix", 'Speedy Express', 'New Orleans Cajun Delights')
# ('Ernst Handel', 10258, 32, 'Mascarpone Fabioli', 'Speedy Express', 'Formaggi Fortini s.r.l.')
# ('Ernst Handel', 10351, 38, 'Côte de Blaye', 'Speedy Express', 'Aux joyeux ecclésiastiques')
# ('Ernst Handel', 10351, 41, "Jack's New England Clam Chowder", 'Speedy Express', 'New England Seafood Cannery')
# ('Ernst Handel', 10351, 44, 'Gula Malacca', 'Speedy Express', 'Leka Trading')
# ('Ernst Handel', 10351, 65, 'Louisiana Fiery Hot Pepper Sauce', 'Speedy Express', 'New Orleans Cajun Delights')
# ('Ernst Handel', 10382, 5, "Chef Anton's Gumbo Mix", 'Speedy Express', 'New Orleans Cajun Delights')
# ('Ernst Handel', 10382, 18, 'Carnarvon Tigers', 'Speedy Express', 'Pavlova, Ltd.')
# ('Ernst Handel', 10382, 29, 'Thüringer Rostbratwurst', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Ernst Handel', 10382, 33, 'Geitost', 'Speedy Express', 'Norske Meierier')
# ('Ernst Handel', 10382, 74, 'Longlife Tofu', 'Speedy Express', 'Tokyo Traders')
# ('Ernst Handel', 10390, 31, 'Gorgonzola Telino', 'Speedy Express', 'Formaggi Fortini s.r.l.')
# ('Ernst Handel', 10390, 35, 'Steeleye Stout', 'Speedy Express', 'Bigfoot Breweries')
# ('Ernst Handel', 10390, 46, 'Spegesild', 'Speedy Express', 'Lyngbysild')
# ('Ernst Handel', 10390, 72, 'Mozzarella di Giovanni', 'Speedy Express', 'Formaggi Fortini s.r.l.')
# ('Ernst Handel', 10430, 17, 'Alice Mutton', 'Speedy Express', 'Pavlova, Ltd.')
# ('Ernst Handel', 10430, 21, "Sir Rodney's Scones", 'Speedy Express', 'Specialty Biscuits, Ltd.')
# ('Ernst Handel', 10430, 56, 'Gnocchi di nonna Alice', 'Speedy Express', 'Pasta Buttini s.r.l.')
# ('Ernst Handel', 10430, 59, 'Raclette Courdavault', 'Speedy Express', 'Gai pâturage')
# ('Ernst Handel', 10368, 21, "Sir Rodney's Scones", 'United Package', 'Specialty Biscuits, Ltd.')
# ('Ernst Handel', 10368, 28, 'Rössle Sauerkraut', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Ernst Handel', 10368, 57, 'Ravioli Angelo', 'United Package', 'Pasta Buttini s.r.l.')
# ('Ernst Handel', 10368, 64, 'Wimmers gute Semmelknödel', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Ernst Handel', 10402, 23, 'Tunnbröd', 'United Package', 'PB Knäckebröd AB')
# ('Ernst Handel', 10402, 63, 'Vegie-spread', 'United Package', 'Pavlova, Ltd.')
# ('Ernst Handel', 10442, 11, 'Queso Cabrales', 'United Package', "Cooperativa de Quesos 'Las Cabras'")
# ('Ernst Handel', 10442, 54, 'Tourtière', 'United Package', 'Ma Maison')
# ('Ernst Handel', 10442, 66, 'Louisiana Hot Spiced Okra', 'United Package', 'New Orleans Cajun Delights')
# ('Ernst Handel', 10263, 16, 'Pavlova', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Ernst Handel', 10263, 24, 'Guaraná Fantástica', 'Federal Shipping', 'Refrescos Americanas LTDA')
# ('Ernst Handel', 10263, 30, 'Nord-Ost Matjeshering', 'Federal Shipping', 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# ('Ernst Handel', 10263, 74, 'Longlife Tofu', 'Federal Shipping', 'Tokyo Traders')
# ('Ernst Handel', 10403, 16, 'Pavlova', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Ernst Handel', 10403, 48, 'Chocolade', 'Federal Shipping', 'Zaanse Snoepfabriek')
# ('FISSA Fabrica Inter. Salchichas S.A.', None, None, None, None, None)
# ('Familia Arquibaldo', 10347, 25, 'NuNuCa Nuß-Nougat-Creme', 'Federal Shipping', 'Heli Süßwaren GmbH & Co. KG')
# ('Familia Arquibaldo', 10347, 39, 'Chartreuse verte', 'Federal Shipping', 'Aux joyeux ecclésiastiques')
# ('Familia Arquibaldo', 10347, 40, 'Boston Crab Meat', 'Federal Shipping', 'New England Seafood Cannery')
# ('Familia Arquibaldo', 10347, 75, 'Rhönbräu Klosterbier', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Familia Arquibaldo', 10386, 24, 'Guaraná Fantástica', 'Federal Shipping', 'Refrescos Americanas LTDA')
# ('Familia Arquibaldo', 10386, 34, 'Sasquatch Ale', 'Federal Shipping', 'Bigfoot Breweries')
# ('Familia Arquibaldo', 10414, 19, 'Teatime Chocolate Biscuits', 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('Familia Arquibaldo', 10414, 33, 'Geitost', 'Federal Shipping', 'Norske Meierier')
# ('Folies gourmandes', 10408, 37, 'Gravad lax', 'Speedy Express', 'Svensk Sjöföda AB')
# ('Folies gourmandes', 10408, 54, 'Tourtière', 'Speedy Express', 'Ma Maison')
# ('Folies gourmandes', 10408, 62, 'Tarte au sucre', 'Speedy Express', "Forêts d'érables")
# ('Folk och fä HB', 10327, 2, 'Chang', 'Speedy Express', 'Exotic Liquid')
# ('Folk och fä HB', 10327, 11, 'Queso Cabrales', 'Speedy Express', "Cooperativa de Quesos 'Las Cabras'")
# ('Folk och fä HB', 10327, 30, 'Nord-Ost Matjeshering', 'Speedy Express', 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# ('Folk och fä HB', 10327, 58, 'Escargots de Bourgogne', 'Speedy Express', 'Escargots Nouveaux')
# ('Folk och fä HB', 10434, 11, 'Queso Cabrales', 'United Package', "Cooperativa de Quesos 'Las Cabras'")
# ('Folk och fä HB', 10434, 76, 'Lakkalikööri', 'United Package', 'Karkki Oy')
# ('Folk och fä HB', 10264, 2, 'Chang', 'Federal Shipping', 'Exotic Liquid')
# ('Folk och fä HB', 10264, 41, "Jack's New England Clam Chowder", 'Federal Shipping', 'New England Seafood Cannery')
# ('Folk och fä HB', 10378, 71, 'Fløtemysost', 'Federal Shipping', 'Norske Meierier')
# ('France restauration', None, None, None, None, None)
# ('Franchi S.p.A.', 10422, 26, 'Gumbär Gummibärchen', 'Speedy Express', 'Heli Süßwaren GmbH & Co. KG')
# ('Frankenversand', 10267, 40, 'Boston Crab Meat', 'Speedy Express', 'New England Seafood Cannery')
# ('Frankenversand', 10267, 59, 'Raclette Courdavault', 'Speedy Express', 'Gai pâturage')
# ('Frankenversand', 10267, 76, 'Lakkalikööri', 'Speedy Express', 'Karkki Oy')
# ('Frankenversand', 10342, 2, 'Chang', 'United Package', 'Exotic Liquid')
# ('Frankenversand', 10342, 31, 'Gorgonzola Telino', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Frankenversand', 10342, 36, 'Inlagd Sill', 'United Package', 'Svensk Sjöföda AB')
# ('Frankenversand', 10342, 55, 'Pâté chinois', 'United Package', 'Ma Maison')
# ('Frankenversand', 10337, 23, 'Tunnbröd', 'Federal Shipping', 'PB Knäckebröd AB')
# ('Frankenversand', 10337, 26, 'Gumbär Gummibärchen', 'Federal Shipping', 'Heli Süßwaren GmbH & Co. KG')
# ('Frankenversand', 10337, 36, 'Inlagd Sill', 'Federal Shipping', 'Svensk Sjöföda AB')
# ('Frankenversand', 10337, 37, 'Gravad lax', 'Federal Shipping', 'Svensk Sjöföda AB')
# ('Frankenversand', 10337, 72, 'Mozzarella di Giovanni', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Frankenversand', 10396, 23, 'Tunnbröd', 'Federal Shipping', 'PB Knäckebröd AB')
# ('Frankenversand', 10396, 71, 'Fløtemysost', 'Federal Shipping', 'Norske Meierier')
# ('Frankenversand', 10396, 72, 'Mozzarella di Giovanni', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Furia Bacalhau e Frutos do Mar', 10328, 59, 'Raclette Courdavault', 'Federal Shipping', 'Gai pâturage')
# ('Furia Bacalhau e Frutos do Mar', 10328, 65, 'Louisiana Fiery Hot Pepper Sauce', 'Federal Shipping', 'New Orleans Cajun Delights')
# ('Furia Bacalhau e Frutos do Mar', 10328, 68, 'Scottish Longbreads', 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('Furia Bacalhau e Frutos do Mar', 10352, 24, 'Guaraná Fantástica', 'Federal Shipping', 'Refrescos Americanas LTDA')
# ('Furia Bacalhau e Frutos do Mar', 10352, 54, 'Tourtière', 'Federal Shipping', 'Ma Maison')
# ('GROSELLA-Restaurante', 10268, 29, 'Thüringer Rostbratwurst', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('GROSELLA-Restaurante', 10268, 72, 'Mozzarella di Giovanni', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Galería del gastrónomo', 10426, 56, 'Gnocchi di nonna Alice', 'Speedy Express', 'Pasta Buttini s.r.l.')
# ('Galería del gastrónomo', 10426, 64, 'Wimmers gute Semmelknödel', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Galería del gastrónomo', 10366, 65, 'Louisiana Fiery Hot Pepper Sauce', 'United Package', 'New Orleans Cajun Delights')
# ('Galería del gastrónomo', 10366, 77, 'Original Frankfurter grüne Soße', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Godos Cocina Típica', 10303, 40, 'Boston Crab Meat', 'United Package', 'New England Seafood Cannery')
# ('Godos Cocina Típica', 10303, 65, 'Louisiana Fiery Hot Pepper Sauce', 'United Package', 'New Orleans Cajun Delights')
# ('Godos Cocina Típica', 10303, 68, 'Scottish Longbreads', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Gourmet Lanchonetes', 10423, 31, 'Gorgonzola Telino', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Gourmet Lanchonetes', 10423, 59, 'Raclette Courdavault', 'Federal Shipping', 'Gai pâturage')
# ('Great Lakes Food Market', None, None, None, None, None)
# ('HILARIÓN-Abastos', 10395, 46, 'Spegesild', 'Speedy Express', 'Lyngbysild')
# ('HILARIÓN-Abastos', 10395, 53, 'Perth Pasties', 'Speedy Express', "G'day, Mate")
# ('HILARIÓN-Abastos', 10395, 69, 'Gudbrandsdalsost', 'Speedy Express', 'Norske Meierier')
# ('HILARIÓN-Abastos', 10257, 27, 'Schoggi Schokolade', 'Federal Shipping', 'Heli Süßwaren GmbH & Co. KG')
# ('HILARIÓN-Abastos', 10257, 39, 'Chartreuse verte', 'Federal Shipping', 'Aux joyeux ecclésiastiques')
# ('HILARIÓN-Abastos', 10257, 77, 'Original Frankfurter grüne Soße', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Hanari Carnes', 10250, 41, "Jack's New England Clam Chowder", 'United Package', 'New England Seafood Cannery')
# ('Hanari Carnes', 10250, 51, 'Manjimup Dried Apples', 'United Package', "G'day, Mate")
# ('Hanari Carnes', 10250, 65, 'Louisiana Fiery Hot Pepper Sauce', 'United Package', 'New Orleans Cajun Delights')
# ('Hanari Carnes', 10253, 31, 'Gorgonzola Telino', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Hanari Carnes', 10253, 39, 'Chartreuse verte', 'United Package', 'Aux joyeux ecclésiastiques')
# ('Hanari Carnes', 10253, 49, 'Maxilaku', 'United Package', 'Karkki Oy')
# ('Hungry Coyote Import Store', 10415, 17, 'Alice Mutton', 'Speedy Express', 'Pavlova, Ltd.')
# ('Hungry Coyote Import Store', 10415, 33, 'Geitost', 'Speedy Express', 'Norske Meierier')
# ('Hungry Coyote Import Store', 10375, 14, 'Tofu', 'United Package', "Mayumi's")
# ('Hungry Coyote Import Store', 10375, 54, 'Tourtière', 'United Package', 'Ma Maison')
# ('Hungry Coyote Import Store', 10394, 13, 'Konbu', 'Federal Shipping', "Mayumi's")
# ('Hungry Coyote Import Store', 10394, 62, 'Tarte au sucre', 'Federal Shipping', "Forêts d'érables")
# ('Hungry Owl All-Night Grocers', 10309, 4, "Chef Anton's Cajun Seasoning", 'Speedy Express', 'New Orleans Cajun Delights')
# ('Hungry Owl All-Night Grocers', 10309, 6, "Grandma's Boysenberry Spread", 'Speedy Express', "Grandma Kelly's Homestead")
# ('Hungry Owl All-Night Grocers', 10309, 42, 'Singaporean Hokkien Fried Mee', 'Speedy Express', 'Leka Trading')
# ('Hungry Owl All-Night Grocers', 10309, 43, 'Ipoh Coffee', 'Speedy Express', 'Leka Trading')
# ('Hungry Owl All-Night Grocers', 10309, 71, 'Fløtemysost', 'Speedy Express', 'Norske Meierier')
# ('Hungry Owl All-Night Grocers', 10298, 2, 'Chang', 'United Package', 'Exotic Liquid')
# ('Hungry Owl All-Night Grocers', 10298, 36, 'Inlagd Sill', 'United Package', 'Svensk Sjöföda AB')
# ('Hungry Owl All-Night Grocers', 10298, 59, 'Raclette Courdavault', 'United Package', 'Gai pâturage')
# ('Hungry Owl All-Night Grocers', 10298, 62, 'Tarte au sucre', 'United Package', "Forêts d'érables")
# ('Hungry Owl All-Night Grocers', 10335, 2, 'Chang', 'United Package', 'Exotic Liquid')
# ('Hungry Owl All-Night Grocers', 10335, 31, 'Gorgonzola Telino', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Hungry Owl All-Night Grocers', 10335, 32, 'Mascarpone Fabioli', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Hungry Owl All-Night Grocers', 10335, 51, 'Manjimup Dried Apples', 'United Package', "G'day, Mate")
# ('Hungry Owl All-Night Grocers', 10429, 50, 'Valkoinen suklaa', 'United Package', 'Karkki Oy')
# ('Hungry Owl All-Night Grocers', 10429, 63, 'Vegie-spread', 'United Package', 'Pavlova, Ltd.')
# ('Hungry Owl All-Night Grocers', 10373, 58, 'Escargots de Bourgogne', 'Federal Shipping', 'Escargots Nouveaux')
# ('Hungry Owl All-Night Grocers', 10373, 71, 'Fløtemysost', 'Federal Shipping', 'Norske Meierier')
# ('Hungry Owl All-Night Grocers', 10380, 30, 'Nord-Ost Matjeshering', 'Federal Shipping', 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# ('Hungry Owl All-Night Grocers', 10380, 53, 'Perth Pasties', 'Federal Shipping', "G'day, Mate")
# ('Hungry Owl All-Night Grocers', 10380, 60, 'Camembert Pierrot', 'Federal Shipping', 'Gai pâturage')
# ('Hungry Owl All-Night Grocers', 10380, 70, 'Outback Lager', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Island Trading', 10315, 34, 'Sasquatch Ale', 'United Package', 'Bigfoot Breweries')
# ('Island Trading', 10315, 70, 'Outback Lager', 'United Package', 'Pavlova, Ltd.')
# ('Island Trading', 10318, 41, "Jack's New England Clam Chowder", 'United Package', 'New England Seafood Cannery')
# ('Island Trading', 10318, 76, 'Lakkalikööri', 'United Package', 'Karkki Oy')
# ('Island Trading', 10321, 35, 'Steeleye Stout', 'United Package', 'Bigfoot Breweries')
# ('Königlich Essen', 10323, 15, 'Genen Shouyu', 'Speedy Express', "Mayumi's")
# ('Königlich Essen', 10323, 25, 'NuNuCa Nuß-Nougat-Creme', 'Speedy Express', 'Heli Süßwaren GmbH & Co. KG')
# ('Königlich Essen', 10323, 39, 'Chartreuse verte', 'Speedy Express', 'Aux joyeux ecclésiastiques')
# ('Königlich Essen', 10325, 6, "Grandma's Boysenberry Spread", 'Federal Shipping', "Grandma Kelly's Homestead")
# ('Königlich Essen', 10325, 13, 'Konbu', 'Federal Shipping', "Mayumi's")
# ('Königlich Essen', 10325, 14, 'Tofu', 'Federal Shipping', "Mayumi's")
# ('Königlich Essen', 10325, 31, 'Gorgonzola Telino', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Königlich Essen', 10325, 72, 'Mozzarella di Giovanni', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('LILA-Supermercado', 10296, 11, 'Queso Cabrales', 'Speedy Express', "Cooperativa de Quesos 'Las Cabras'")
# ('LILA-Supermercado', 10296, 16, 'Pavlova', 'Speedy Express', 'Pavlova, Ltd.')
# ('LILA-Supermercado', 10296, 69, 'Gudbrandsdalsost', 'Speedy Express', 'Norske Meierier')
# ('LILA-Supermercado', 10330, 26, 'Gumbär Gummibärchen', 'Speedy Express', 'Heli Süßwaren GmbH & Co. KG')
# ('LILA-Supermercado', 10330, 72, 'Mozzarella di Giovanni', 'Speedy Express', 'Formaggi Fortini s.r.l.')
# ('LILA-Supermercado', 10283, 15, 'Genen Shouyu', 'Federal Shipping', "Mayumi's")
# ('LILA-Supermercado', 10283, 19, 'Teatime Chocolate Biscuits', 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('LILA-Supermercado', 10283, 60, 'Camembert Pierrot', 'Federal Shipping', 'Gai pâturage')
# ('LILA-Supermercado', 10283, 72, 'Mozzarella di Giovanni', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('LILA-Supermercado', 10357, 10, 'Ikura', 'Federal Shipping', 'Tokyo Traders')
# ('LILA-Supermercado', 10357, 26, 'Gumbär Gummibärchen', 'Federal Shipping', 'Heli Süßwaren GmbH & Co. KG')
# ('LILA-Supermercado', 10357, 60, 'Camembert Pierrot', 'Federal Shipping', 'Gai pâturage')
# ('LILA-Supermercado', 10381, 74, 'Longlife Tofu', 'Federal Shipping', 'Tokyo Traders')
# ('LINO-Delicateses', 10405, 3, 'Aniseed Syrup', 'Speedy Express', 'Exotic Liquid')
# ("La corne d'abondance", None, None, None, None, None)
# ("La maison d'Asie", 10358, 24, 'Guaraná Fantástica', 'Speedy Express', 'Refrescos Americanas LTDA')
# ("La maison d'Asie", 10358, 34, 'Sasquatch Ale', 'Speedy Express', 'Bigfoot Breweries')
# ("La maison d'Asie", 10358, 36, 'Inlagd Sill', 'Speedy Express', 'Svensk Sjöföda AB')
# ("La maison d'Asie", 10371, 36, 'Inlagd Sill', 'Speedy Express', 'Svensk Sjöföda AB')
# ("La maison d'Asie", 10350, 50, 'Valkoinen suklaa', 'United Package', 'Karkki Oy')
# ("La maison d'Asie", 10350, 69, 'Gudbrandsdalsost', 'United Package', 'Norske Meierier')
# ("La maison d'Asie", 10413, 1, 'Chais', 'United Package', 'Exotic Liquid')
# ("La maison d'Asie", 10413, 62, 'Tarte au sucre', 'United Package', "Forêts d'érables")
# ("La maison d'Asie", 10413, 76, 'Lakkalikööri', 'United Package', 'Karkki Oy')
# ("La maison d'Asie", 10425, 55, 'Pâté chinois', 'United Package', 'Ma Maison')
# ("La maison d'Asie", 10425, 76, 'Lakkalikööri', 'United Package', 'Karkki Oy')
# ('Laughing Bacchus Wine Cellars', None, None, None, None, None)
# ('Lazy K Kountry Store', None, None, None, None, None)
# ('Lehmanns Marktstand', 10284, 27, 'Schoggi Schokolade', 'Speedy Express', 'Heli Süßwaren GmbH & Co. KG')
# ('Lehmanns Marktstand', 10284, 44, 'Gula Malacca', 'Speedy Express', 'Leka Trading')
# ('Lehmanns Marktstand', 10284, 60, 'Camembert Pierrot', 'Speedy Express', 'Gai pâturage')
# ('Lehmanns Marktstand', 10284, 67, 'Laughing Lumberjack Lager', 'Speedy Express', 'Bigfoot Breweries')
# ('Lehmanns Marktstand', 10343, 64, 'Wimmers gute Semmelknödel', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Lehmanns Marktstand', 10343, 68, 'Scottish Longbreads', 'Speedy Express', 'Specialty Biscuits, Ltd.')
# ('Lehmanns Marktstand', 10343, 76, 'Lakkalikööri', 'Speedy Express', 'Karkki Oy')
# ('Lehmanns Marktstand', 10279, 17, 'Alice Mutton', 'United Package', 'Pavlova, Ltd.')
# ("Let's Stop N Shop", None, None, None, None, None)
# ('Lonesome Pine Restaurant', 10317, 1, 'Chais', 'Speedy Express', 'Exotic Liquid')
# ('Lonesome Pine Restaurant', 10307, 62, 'Tarte au sucre', 'United Package', "Forêts d'érables")
# ('Lonesome Pine Restaurant', 10307, 68, 'Scottish Longbreads', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Magazzini Alimentari Riuniti', 10275, 24, 'Guaraná Fantástica', 'Speedy Express', 'Refrescos Americanas LTDA')
# ('Magazzini Alimentari Riuniti', 10275, 59, 'Raclette Courdavault', 'Speedy Express', 'Gai pâturage')
# ('Magazzini Alimentari Riuniti', 10404, 26, 'Gumbär Gummibärchen', 'Speedy Express', 'Heli Süßwaren GmbH & Co. KG')
# ('Magazzini Alimentari Riuniti', 10404, 42, 'Singaporean Hokkien Fried Mee', 'Speedy Express', 'Leka Trading')
# ('Magazzini Alimentari Riuniti', 10404, 49, 'Maxilaku', 'Speedy Express', 'Karkki Oy')
# ('Magazzini Alimentari Riuniti', 10300, 66, 'Louisiana Hot Spiced Okra', 'United Package', 'New Orleans Cajun Delights')
# ('Magazzini Alimentari Riuniti', 10300, 68, 'Scottish Longbreads', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Maison Dewey', None, None, None, None, None)
# ('Morgenstern Gesundkost', 10277, 28, 'Rössle Sauerkraut', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Morgenstern Gesundkost', 10277, 62, 'Tarte au sucre', 'Federal Shipping', "Forêts d'érables")
# ('Mère Paillarde', 10332, 18, 'Carnarvon Tigers', 'United Package', 'Pavlova, Ltd.')
# ('Mère Paillarde', 10332, 42, 'Singaporean Hokkien Fried Mee', 'United Package', 'Leka Trading')
# ('Mère Paillarde', 10332, 47, 'Zaanse koeken', 'United Package', 'Zaanse Snoepfabriek')
# ('Mère Paillarde', 10339, 4, "Chef Anton's Cajun Seasoning", 'United Package', 'New Orleans Cajun Delights')
# ('Mère Paillarde', 10339, 17, 'Alice Mutton', 'United Package', 'Pavlova, Ltd.')
# ('Mère Paillarde', 10339, 62, 'Tarte au sucre', 'United Package', "Forêts d'érables")
# ('Mère Paillarde', 10376, 31, 'Gorgonzola Telino', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Mère Paillarde', 10424, 35, 'Steeleye Stout', 'United Package', 'Bigfoot Breweries')
# ('Mère Paillarde', 10424, 38, 'Côte de Blaye', 'United Package', 'Aux joyeux ecclésiastiques')
# ('Mère Paillarde', 10424, 68, 'Scottish Longbreads', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Mère Paillarde', 10439, 12, 'Queso Manchego La Pastora', 'Federal Shipping', "Cooperativa de Quesos 'Las Cabras'")
# ('Mère Paillarde', 10439, 16, 'Pavlova', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Mère Paillarde', 10439, 64, 'Wimmers gute Semmelknödel', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Mère Paillarde', 10439, 74, 'Longlife Tofu', 'Federal Shipping', 'Tokyo Traders')
# ('North/South', None, None, None, None, None)
# ('Océano Atlántico Ltda.', 10409, 14, 'Tofu', 'Speedy Express', "Mayumi's")
# ('Océano Atlántico Ltda.', 10409, 21, "Sir Rodney's Scones", 'Speedy Express', 'Specialty Biscuits, Ltd.')
# ('Old World Delicatessen', 10260, 41, "Jack's New England Clam Chowder", 'Speedy Express', 'New England Seafood Cannery')
# ('Old World Delicatessen', 10260, 57, 'Ravioli Angelo', 'Speedy Express', 'Pasta Buttini s.r.l.')
# ('Old World Delicatessen', 10260, 62, 'Tarte au sucre', 'Speedy Express', "Forêts d'érables")
# ('Old World Delicatessen', 10260, 70, 'Outback Lager', 'Speedy Express', 'Pavlova, Ltd.')
# ('Old World Delicatessen', 10441, 27, 'Schoggi Schokolade', 'United Package', 'Heli Süßwaren GmbH & Co. KG')
# ('Old World Delicatessen', 10305, 18, 'Carnarvon Tigers', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Old World Delicatessen', 10305, 29, 'Thüringer Rostbratwurst', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Old World Delicatessen', 10305, 39, 'Chartreuse verte', 'Federal Shipping', 'Aux joyeux ecclésiastiques')
# ('Old World Delicatessen', 10338, 17, 'Alice Mutton', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Old World Delicatessen', 10338, 30, 'Nord-Ost Matjeshering', 'Federal Shipping', 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# ('Ottilies Käseladen', 10407, 11, 'Queso Cabrales', 'United Package', "Cooperativa de Quesos 'Las Cabras'")
# ('Ottilies Käseladen', 10407, 69, 'Gudbrandsdalsost', 'United Package', 'Norske Meierier')
# ('Ottilies Käseladen', 10407, 71, 'Fløtemysost', 'United Package', 'Norske Meierier')
# ('Paris spécialités', None, None, None, None, None)
# ('Pericles Comidas clásicas', 10322, 52, 'Filo Mix', 'Federal Shipping', "G'day, Mate")
# ('Pericles Comidas clásicas', 10354, 1, 'Chais', 'Federal Shipping', 'Exotic Liquid')
# ('Pericles Comidas clásicas', 10354, 29, 'Thüringer Rostbratwurst', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Piccolo und mehr', 10427, 14, 'Tofu', 'United Package', "Mayumi's")
# ('Piccolo und mehr', 10353, 11, 'Queso Cabrales', 'Federal Shipping', "Cooperativa de Quesos 'Las Cabras'")
# ('Piccolo und mehr', 10353, 38, 'Côte de Blaye', 'Federal Shipping', 'Aux joyeux ecclésiastiques')
# ('Piccolo und mehr', 10392, 69, 'Gudbrandsdalsost', 'Federal Shipping', 'Norske Meierier')
# ('Princesa Isabel Vinhoss', 10397, 21, "Sir Rodney's Scones", 'Speedy Express', 'Specialty Biscuits, Ltd.')
# ('Princesa Isabel Vinhoss', 10397, 51, 'Manjimup Dried Apples', 'Speedy Express', "G'day, Mate")
# ('Princesa Isabel Vinhoss', 10336, 4, "Chef Anton's Cajun Seasoning", 'United Package', 'New Orleans Cajun Delights')
# ('Princesa Isabel Vinhoss', 10433, 56, 'Gnocchi di nonna Alice', 'Federal Shipping', 'Pasta Buttini s.r.l.')
# ('QUICK-Stop', 10418, 2, 'Chang', 'Speedy Express', 'Exotic Liquid')
# ('QUICK-Stop', 10418, 47, 'Zaanse koeken', 'Speedy Express', 'Zaanse Snoepfabriek')
# ('QUICK-Stop', 10418, 61, "Sirop d'érable", 'Speedy Express', "Forêts d'érables")
# ('QUICK-Stop', 10418, 74, 'Longlife Tofu', 'Speedy Express', 'Tokyo Traders')
# ('QUICK-Stop', 10285, 1, 'Chais', 'United Package', 'Exotic Liquid')
# ('QUICK-Stop', 10285, 40, 'Boston Crab Meat', 'United Package', 'New England Seafood Cannery')
# ('QUICK-Stop', 10285, 53, 'Perth Pasties', 'United Package', "G'day, Mate")
# ('QUICK-Stop', 10313, 36, 'Inlagd Sill', 'United Package', 'Svensk Sjöföda AB')
# ('QUICK-Stop', 10345, 8, 'Northwoods Cranberry Sauce', 'United Package', "Grandma Kelly's Homestead")
# ('QUICK-Stop', 10345, 19, 'Teatime Chocolate Biscuits', 'United Package', 'Specialty Biscuits, Ltd.')
# ('QUICK-Stop', 10345, 42, 'Singaporean Hokkien Fried Mee', 'United Package', 'Leka Trading')
# ('QUICK-Stop', 10361, 39, 'Chartreuse verte', 'United Package', 'Aux joyeux ecclésiastiques')
# ('QUICK-Stop', 10361, 60, 'Camembert Pierrot', 'United Package', 'Gai pâturage')
# ('QUICK-Stop', 10273, 10, 'Ikura', 'Federal Shipping', 'Tokyo Traders')
# ('QUICK-Stop', 10273, 31, 'Gorgonzola Telino', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('QUICK-Stop', 10273, 33, 'Geitost', 'Federal Shipping', 'Norske Meierier')
# ('QUICK-Stop', 10273, 40, 'Boston Crab Meat', 'Federal Shipping', 'New England Seafood Cannery')
# ('QUICK-Stop', 10273, 76, 'Lakkalikööri', 'Federal Shipping', 'Karkki Oy')
# ('QUICK-Stop', 10286, 35, 'Steeleye Stout', 'Federal Shipping', 'Bigfoot Breweries')
# ('QUICK-Stop', 10286, 62, 'Tarte au sucre', 'Federal Shipping', "Forêts d'érables")
# ('Que Delícia', 10379, 41, "Jack's New England Clam Chowder", 'Speedy Express', 'New England Seafood Cannery')
# ('Que Delícia', 10379, 63, 'Vegie-spread', 'Speedy Express', 'Pavlova, Ltd.')
# ('Que Delícia', 10379, 65, 'Louisiana Fiery Hot Pepper Sauce', 'Speedy Express', 'New Orleans Cajun Delights')
# ('Que Delícia', 10421, 19, 'Teatime Chocolate Biscuits', 'Speedy Express', 'Specialty Biscuits, Ltd.')
# ('Que Delícia', 10421, 26, 'Gumbär Gummibärchen', 'Speedy Express', 'Heli Süßwaren GmbH & Co. KG')
# ('Que Delícia', 10421, 53, 'Perth Pasties', 'Speedy Express', "G'day, Mate")
# ('Que Delícia', 10421, 77, 'Original Frankfurter grüne Soße', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Que Delícia', 10261, 21, "Sir Rodney's Scones", 'United Package', 'Specialty Biscuits, Ltd.')
# ('Que Delícia', 10261, 35, 'Steeleye Stout', 'United Package', 'Bigfoot Breweries')
# ('Que Delícia', 10291, 13, 'Konbu', 'United Package', "Mayumi's")
# ('Que Delícia', 10291, 44, 'Gula Malacca', 'United Package', 'Leka Trading')
# ('Que Delícia', 10291, 51, 'Manjimup Dried Apples', 'United Package', "G'day, Mate")
# ('Queen Cozinha', 10406, 1, 'Chais', 'Speedy Express', 'Exotic Liquid')
# ('Queen Cozinha', 10406, 21, "Sir Rodney's Scones", 'Speedy Express', 'Specialty Biscuits, Ltd.')
# ('Queen Cozinha', 10406, 28, 'Rössle Sauerkraut', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Queen Cozinha', 10406, 36, 'Inlagd Sill', 'Speedy Express', 'Svensk Sjöföda AB')
# ('Queen Cozinha', 10406, 40, 'Boston Crab Meat', 'Speedy Express', 'New England Seafood Cannery')
# ('Queen Cozinha', 10372, 20, "Sir Rodney's Marmalade", 'United Package', 'Specialty Biscuits, Ltd.')
# ('Queen Cozinha', 10372, 38, 'Côte de Blaye', 'United Package', 'Aux joyeux ecclésiastiques')
# ('Queen Cozinha', 10372, 60, 'Camembert Pierrot', 'United Package', 'Gai pâturage')
# ('Queen Cozinha', 10372, 72, 'Mozzarella di Giovanni', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Rancho grande', None, None, None, None, None)
# ('Rattlesnake Canyon Grocery', 10401, 30, 'Nord-Ost Matjeshering', 'Speedy Express', 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# ('Rattlesnake Canyon Grocery', 10401, 56, 'Gnocchi di nonna Alice', 'Speedy Express', 'Pasta Buttini s.r.l.')
# ('Rattlesnake Canyon Grocery', 10401, 65, 'Louisiana Fiery Hot Pepper Sauce', 'Speedy Express', 'New Orleans Cajun Delights')
# ('Rattlesnake Canyon Grocery', 10401, 71, 'Fløtemysost', 'Speedy Express', 'Norske Meierier')
# ('Rattlesnake Canyon Grocery', 10272, 20, "Sir Rodney's Marmalade", 'United Package', 'Specialty Biscuits, Ltd.')
# ('Rattlesnake Canyon Grocery', 10272, 31, 'Gorgonzola Telino', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Rattlesnake Canyon Grocery', 10272, 72, 'Mozzarella di Giovanni', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Rattlesnake Canyon Grocery', 10294, 1, 'Chais', 'United Package', 'Exotic Liquid')
# ('Rattlesnake Canyon Grocery', 10294, 17, 'Alice Mutton', 'United Package', 'Pavlova, Ltd.')
# ('Rattlesnake Canyon Grocery', 10294, 43, 'Ipoh Coffee', 'United Package', 'Leka Trading')
# ('Rattlesnake Canyon Grocery', 10294, 60, 'Camembert Pierrot', 'United Package', 'Gai pâturage')
# ('Rattlesnake Canyon Grocery', 10294, 75, 'Rhönbräu Klosterbier', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Rattlesnake Canyon Grocery', 10314, 32, 'Mascarpone Fabioli', 'United Package', 'Formaggi Fortini s.r.l.')
# ('Rattlesnake Canyon Grocery', 10314, 58, 'Escargots de Bourgogne', 'United Package', 'Escargots Nouveaux')
# ('Rattlesnake Canyon Grocery', 10314, 62, 'Tarte au sucre', 'United Package', "Forêts d'érables")
# ('Rattlesnake Canyon Grocery', 10262, 5, "Chef Anton's Gumbo Mix", 'Federal Shipping', 'New Orleans Cajun Delights')
# ('Rattlesnake Canyon Grocery', 10262, 7, "Uncle Bob's Organic Dried Pears", 'Federal Shipping', "Grandma Kelly's Homestead")
# ('Rattlesnake Canyon Grocery', 10262, 56, 'Gnocchi di nonna Alice', 'Federal Shipping', 'Pasta Buttini s.r.l.')
# ('Rattlesnake Canyon Grocery', 10316, 41, "Jack's New England Clam Chowder", 'Federal Shipping', 'New England Seafood Cannery')
# ('Rattlesnake Canyon Grocery', 10316, 62, 'Tarte au sucre', 'Federal Shipping', "Forêts d'érables")
# ('Rattlesnake Canyon Grocery', 10346, 17, 'Alice Mutton', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Rattlesnake Canyon Grocery', 10346, 56, 'Gnocchi di nonna Alice', 'Federal Shipping', 'Pasta Buttini s.r.l.')
# ('Reggiani Caseifici', 10288, 54, 'Tourtière', 'Speedy Express', 'Ma Maison')
# ('Reggiani Caseifici', 10288, 68, 'Scottish Longbreads', 'Speedy Express', 'Specialty Biscuits, Ltd.')
# ('Reggiani Caseifici', 10428, 46, 'Spegesild', 'Speedy Express', 'Lyngbysild')
# ('Reggiani Caseifici', 10443, 11, 'Queso Cabrales', 'Speedy Express', "Cooperativa de Quesos 'Las Cabras'")
# ('Reggiani Caseifici', 10443, 28, 'Rössle Sauerkraut', 'Speedy Express', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Ricardo Adocicados', 10299, 19, 'Teatime Chocolate Biscuits', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Ricardo Adocicados', 10299, 70, 'Outback Lager', 'United Package', 'Pavlova, Ltd.')
# ('Ricardo Adocicados', 10287, 16, 'Pavlova', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Ricardo Adocicados', 10287, 34, 'Sasquatch Ale', 'Federal Shipping', 'Bigfoot Breweries')
# ('Ricardo Adocicados', 10287, 46, 'Spegesild', 'Federal Shipping', 'Lyngbysild')
# ('Richter Supermarkt', 10419, 60, 'Camembert Pierrot', 'United Package', 'Gai pâturage')
# ('Richter Supermarkt', 10419, 69, 'Gudbrandsdalsost', 'United Package', 'Norske Meierier')
# ('Richter Supermarkt', 10255, 2, 'Chang', 'Federal Shipping', 'Exotic Liquid')
# ('Richter Supermarkt', 10255, 16, 'Pavlova', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Richter Supermarkt', 10255, 36, 'Inlagd Sill', 'Federal Shipping', 'Svensk Sjöföda AB')
# ('Richter Supermarkt', 10255, 59, 'Raclette Courdavault', 'Federal Shipping', 'Gai pâturage')
# ('Romero y tomillo', 10281, 19, 'Teatime Chocolate Biscuits', 'Speedy Express', 'Specialty Biscuits, Ltd.')
# ('Romero y tomillo', 10281, 24, 'Guaraná Fantástica', 'Speedy Express', 'Refrescos Americanas LTDA')
# ('Romero y tomillo', 10281, 35, 'Steeleye Stout', 'Speedy Express', 'Bigfoot Breweries')
# ('Romero y tomillo', 10282, 30, 'Nord-Ost Matjeshering', 'Speedy Express', 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# ('Romero y tomillo', 10282, 57, 'Ravioli Angelo', 'Speedy Express', 'Pasta Buttini s.r.l.')
# ('Romero y tomillo', 10306, 30, 'Nord-Ost Matjeshering', 'Federal Shipping', 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# ('Romero y tomillo', 10306, 53, 'Perth Pasties', 'Federal Shipping', "G'day, Mate")
# ('Romero y tomillo', 10306, 54, 'Tourtière', 'Federal Shipping', 'Ma Maison')
# ('Santé Gourmet', 10387, 24, 'Guaraná Fantástica', 'United Package', 'Refrescos Americanas LTDA')
# ('Santé Gourmet', 10387, 28, 'Rössle Sauerkraut', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Santé Gourmet', 10387, 59, 'Raclette Courdavault', 'United Package', 'Gai pâturage')
# ('Santé Gourmet', 10387, 71, 'Fløtemysost', 'United Package', 'Norske Meierier')
# ('Save-a-lot Markets', 10324, 16, 'Pavlova', 'Speedy Express', 'Pavlova, Ltd.')
# ('Save-a-lot Markets', 10324, 35, 'Steeleye Stout', 'Speedy Express', 'Bigfoot Breweries')
# ('Save-a-lot Markets', 10324, 46, 'Spegesild', 'Speedy Express', 'Lyngbysild')
# ('Save-a-lot Markets', 10324, 59, 'Raclette Courdavault', 'Speedy Express', 'Gai pâturage')
# ('Save-a-lot Markets', 10324, 63, 'Vegie-spread', 'Speedy Express', 'Pavlova, Ltd.')
# ('Save-a-lot Markets', 10440, 2, 'Chang', 'United Package', 'Exotic Liquid')
# ('Save-a-lot Markets', 10440, 16, 'Pavlova', 'United Package', 'Pavlova, Ltd.')
# ('Save-a-lot Markets', 10440, 29, 'Thüringer Rostbratwurst', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Save-a-lot Markets', 10440, 61, "Sirop d'érable", 'United Package', "Forêts d'érables")
# ('Save-a-lot Markets', 10393, 2, 'Chang', 'Federal Shipping', 'Exotic Liquid')
# ('Save-a-lot Markets', 10393, 14, 'Tofu', 'Federal Shipping', "Mayumi's")
# ('Save-a-lot Markets', 10393, 25, 'NuNuCa Nuß-Nougat-Creme', 'Federal Shipping', 'Heli Süßwaren GmbH & Co. KG')
# ('Save-a-lot Markets', 10393, 26, 'Gumbär Gummibärchen', 'Federal Shipping', 'Heli Süßwaren GmbH & Co. KG')
# ('Save-a-lot Markets', 10393, 31, 'Gorgonzola Telino', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Save-a-lot Markets', 10398, 35, 'Steeleye Stout', 'Federal Shipping', 'Bigfoot Breweries')
# ('Save-a-lot Markets', 10398, 55, 'Pâté chinois', 'Federal Shipping', 'Ma Maison')
# ('Seven Seas Imports', 10388, 45, 'Røgede sild', 'Speedy Express', 'Lyngbysild')
# ('Seven Seas Imports', 10388, 52, 'Filo Mix', 'Speedy Express', "G'day, Mate")
# ('Seven Seas Imports', 10388, 53, 'Perth Pasties', 'Speedy Express', "G'day, Mate")
# ('Seven Seas Imports', 10359, 16, 'Pavlova', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Seven Seas Imports', 10359, 31, 'Gorgonzola Telino', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Seven Seas Imports', 10359, 60, 'Camembert Pierrot', 'Federal Shipping', 'Gai pâturage')
# ('Seven Seas Imports', 10377, 28, 'Rössle Sauerkraut', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Seven Seas Imports', 10377, 39, 'Chartreuse verte', 'Federal Shipping', 'Aux joyeux ecclésiastiques')
# ('Simons bistro', 10341, 33, 'Geitost', 'Federal Shipping', 'Norske Meierier')
# ('Simons bistro', 10341, 59, 'Raclette Courdavault', 'Federal Shipping', 'Gai pâturage')
# ('Simons bistro', 10417, 38, 'Côte de Blaye', 'Federal Shipping', 'Aux joyeux ecclésiastiques')
# ('Simons bistro', 10417, 46, 'Spegesild', 'Federal Shipping', 'Lyngbysild')
# ('Simons bistro', 10417, 68, 'Scottish Longbreads', 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('Simons bistro', 10417, 77, 'Original Frankfurter grüne Soße', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Split Rail Beer & Ale', 10349, 54, 'Tourtière', 'Speedy Express', 'Ma Maison')
# ('Split Rail Beer & Ale', 10271, 33, 'Geitost', 'United Package', 'Norske Meierier')
# ('Split Rail Beer & Ale', 10329, 19, 'Teatime Chocolate Biscuits', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Split Rail Beer & Ale', 10329, 30, 'Nord-Ost Matjeshering', 'United Package', 'Nord-Ost-Fisch Handelsgesellschaft mbH')
# ('Split Rail Beer & Ale', 10329, 38, 'Côte de Blaye', 'United Package', 'Aux joyeux ecclésiastiques')
# ('Split Rail Beer & Ale', 10329, 56, 'Gnocchi di nonna Alice', 'United Package', 'Pasta Buttini s.r.l.')
# ('Split Rail Beer & Ale', 10369, 29, 'Thüringer Rostbratwurst', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Split Rail Beer & Ale', 10369, 56, 'Gnocchi di nonna Alice', 'United Package', 'Pasta Buttini s.r.l.')
# ('Split Rail Beer & Ale', 10385, 7, "Uncle Bob's Organic Dried Pears", 'United Package', "Grandma Kelly's Homestead")
# ('Split Rail Beer & Ale', 10385, 60, 'Camembert Pierrot', 'United Package', 'Gai pâturage')
# ('Split Rail Beer & Ale', 10385, 68, 'Scottish Longbreads', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Split Rail Beer & Ale', 10432, 26, 'Gumbär Gummibärchen', 'United Package', 'Heli Süßwaren GmbH & Co. KG')
# ('Split Rail Beer & Ale', 10432, 54, 'Tourtière', 'United Package', 'Ma Maison')
# ('Spécialités du monde', None, None, None, None, None)
# ('Suprêmes délices', 10252, 20, "Sir Rodney's Marmalade", 'United Package', 'Specialty Biscuits, Ltd.')
# ('Suprêmes délices', 10252, 33, 'Geitost', 'United Package', 'Norske Meierier')
# ('Suprêmes délices', 10252, 60, 'Camembert Pierrot', 'United Package', 'Gai pâturage')
# ('Suprêmes délices', 10302, 17, 'Alice Mutton', 'United Package', 'Pavlova, Ltd.')
# ('Suprêmes délices', 10302, 28, 'Rössle Sauerkraut', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Suprêmes délices', 10302, 43, 'Ipoh Coffee', 'United Package', 'Leka Trading')
# ('The Big Cheese', 10310, 16, 'Pavlova', 'United Package', 'Pavlova, Ltd.')
# ('The Big Cheese', 10310, 62, 'Tarte au sucre', 'United Package', "Forêts d'érables")
# ('The Cracker Box', None, None, None, None, None)
# ('Toms Spezialitäten', 10438, 19, 'Teatime Chocolate Biscuits', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Toms Spezialitäten', 10438, 34, 'Sasquatch Ale', 'United Package', 'Bigfoot Breweries')
# ('Toms Spezialitäten', 10438, 57, 'Ravioli Angelo', 'United Package', 'Pasta Buttini s.r.l.')
# ('Tortuga Restaurante', 10304, 49, 'Maxilaku', 'United Package', 'Karkki Oy')
# ('Tortuga Restaurante', 10304, 59, 'Raclette Courdavault', 'United Package', 'Gai pâturage')
# ('Tortuga Restaurante', 10304, 71, 'Fløtemysost', 'United Package', 'Norske Meierier')
# ('Tortuga Restaurante', 10276, 10, 'Ikura', 'Federal Shipping', 'Tokyo Traders')
# ('Tortuga Restaurante', 10276, 13, 'Konbu', 'Federal Shipping', "Mayumi's")
# ('Tortuga Restaurante', 10293, 18, 'Carnarvon Tigers', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Tortuga Restaurante', 10293, 24, 'Guaraná Fantástica', 'Federal Shipping', 'Refrescos Americanas LTDA')
# ('Tortuga Restaurante', 10293, 63, 'Vegie-spread', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Tortuga Restaurante', 10293, 75, 'Rhönbräu Klosterbier', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Tortuga Restaurante', 10319, 17, 'Alice Mutton', 'Federal Shipping', 'Pavlova, Ltd.')
# ('Tortuga Restaurante', 10319, 28, 'Rössle Sauerkraut', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Tortuga Restaurante', 10319, 76, 'Lakkalikööri', 'Federal Shipping', 'Karkki Oy')
# ('Tradição Hipermercados', 10249, 14, 'Tofu', 'Speedy Express', "Mayumi's")
# ('Tradição Hipermercados', 10249, 51, 'Manjimup Dried Apples', 'Speedy Express', "G'day, Mate")
# ('Tradição Hipermercados', 10292, 20, "Sir Rodney's Marmalade", 'United Package', 'Specialty Biscuits, Ltd.')
# ("Trail's Head Gourmet Provisioners", None, None, None, None, None)
# ('Vaffeljernet', 10367, 34, 'Sasquatch Ale', 'Federal Shipping', 'Bigfoot Breweries')
# ('Vaffeljernet', 10367, 54, 'Tourtière', 'Federal Shipping', 'Ma Maison')
# ('Vaffeljernet', 10367, 65, 'Louisiana Fiery Hot Pepper Sauce', 'Federal Shipping', 'New Orleans Cajun Delights')
# ('Vaffeljernet', 10367, 77, 'Original Frankfurter grüne Soße', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Vaffeljernet', 10399, 68, 'Scottish Longbreads', 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('Vaffeljernet', 10399, 71, 'Fløtemysost', 'Federal Shipping', 'Norske Meierier')
# ('Vaffeljernet', 10399, 76, 'Lakkalikööri', 'Federal Shipping', 'Karkki Oy')
# ('Vaffeljernet', 10399, 77, 'Original Frankfurter grüne Soße', 'Federal Shipping', 'Plutzer Lebensmittelgroßmärkte AG')
# ('Victuailles en stock', 10251, 22, "Gustaf's Knäckebröd", 'Speedy Express', 'PB Knäckebröd AB')
# ('Victuailles en stock', 10251, 57, 'Ravioli Angelo', 'Speedy Express', 'Pasta Buttini s.r.l.')
# ('Victuailles en stock', 10251, 65, 'Louisiana Fiery Hot Pepper Sauce', 'Speedy Express', 'New Orleans Cajun Delights')
# ('Victuailles en stock', 10334, 52, 'Filo Mix', 'United Package', "G'day, Mate")
# ('Victuailles en stock', 10334, 68, 'Scottish Longbreads', 'United Package', 'Specialty Biscuits, Ltd.')
# ('Vins et alcools Chevalier', 10274, 71, 'Fløtemysost', 'Speedy Express', 'Norske Meierier')
# ('Vins et alcools Chevalier', 10274, 72, 'Mozzarella di Giovanni', 'Speedy Express', 'Formaggi Fortini s.r.l.')
# ('Vins et alcools Chevalier', 10295, 56, 'Gnocchi di nonna Alice', 'United Package', 'Pasta Buttini s.r.l.')
# ('Wartian Herkku', 10270, 36, 'Inlagd Sill', 'Speedy Express', 'Svensk Sjöföda AB')
# ('Wartian Herkku', 10270, 43, 'Ipoh Coffee', 'Speedy Express', 'Leka Trading')
# ('Wartian Herkku', 10437, 53, 'Perth Pasties', 'Speedy Express', "G'day, Mate")
# ('Wartian Herkku', 10412, 14, 'Tofu', 'United Package', "Mayumi's")
# ('Wartian Herkku', 10266, 12, 'Queso Manchego La Pastora', 'Federal Shipping', "Cooperativa de Quesos 'Las Cabras'")
# ('Wartian Herkku', 10320, 71, 'Fløtemysost', 'Federal Shipping', 'Norske Meierier')
# ('Wartian Herkku', 10333, 14, 'Tofu', 'Federal Shipping', "Mayumi's")
# ('Wartian Herkku', 10333, 21, "Sir Rodney's Scones", 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('Wartian Herkku', 10333, 71, 'Fløtemysost', 'Federal Shipping', 'Norske Meierier')
# ('Wartian Herkku', 10416, 19, 'Teatime Chocolate Biscuits', 'Federal Shipping', 'Specialty Biscuits, Ltd.')
# ('Wartian Herkku', 10416, 53, 'Perth Pasties', 'Federal Shipping', "G'day, Mate")
# ('Wartian Herkku', 10416, 57, 'Ravioli Angelo', 'Federal Shipping', 'Pasta Buttini s.r.l.')
# ('Wellington Importadora', 10420, 9, 'Mishi Kobe Niku', 'Speedy Express', 'Tokyo Traders')
# ('Wellington Importadora', 10420, 13, 'Konbu', 'Speedy Express', "Mayumi's")
# ('Wellington Importadora', 10420, 70, 'Outback Lager', 'Speedy Express', 'Pavlova, Ltd.')
# ('Wellington Importadora', 10420, 73, 'Röd Kaviar', 'Speedy Express', 'Svensk Sjöföda AB')
# ('Wellington Importadora', 10256, 53, 'Perth Pasties', 'United Package', "G'day, Mate")
# ('Wellington Importadora', 10256, 77, 'Original Frankfurter grüne Soße', 'United Package', 'Plutzer Lebensmittelgroßmärkte AG')
# ('White Clover Markets', 10269, 33, 'Geitost', 'Speedy Express', 'Norske Meierier')
# ('White Clover Markets', 10269, 72, 'Mozzarella di Giovanni', 'Speedy Express', 'Formaggi Fortini s.r.l.')
# ('White Clover Markets', 10344, 4, "Chef Anton's Cajun Seasoning", 'United Package', 'New Orleans Cajun Delights')
# ('White Clover Markets', 10344, 8, 'Northwoods Cranberry Sauce', 'United Package', "Grandma Kelly's Homestead")
# ('Wilman Kala', 10248, 11, 'Queso Cabrales', 'Federal Shipping', "Cooperativa de Quesos 'Las Cabras'")
# ('Wilman Kala', 10248, 42, 'Singaporean Hokkien Fried Mee', 'Federal Shipping', 'Leka Trading')
# ('Wilman Kala', 10248, 72, 'Mozzarella di Giovanni', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Wolski', 10374, 31, 'Gorgonzola Telino', 'Federal Shipping', 'Formaggi Fortini s.r.l.')
# ('Wolski', 10374, 58, 'Escargots de Bourgogne', 'Federal Shipping', 'Escargots Nouveaux')

# %%
from sqlalchemy import cast

# %%
columns = [customers.c.CustomerName, orders.c.OrderID,order_detail.c.ProductID,product.c.ProductName,cast((order_detail.c.Quantity * product.c.Price),
Numeric(12,2)).label('inv_cost')]
all_orders = select(columns)
all_orders = all_orders.select_from(customers.outerjoin(orders).outerjoin(order_detail).outerjoin(product))
all_orders = all_orders.order_by(customers.c.CustomerName)
result = connection.execute(all_orders).fetchall()
for row in result:
    print(row)
# Out:
# ('Alfreds Futterkiste', None, None, None, None)
# ('Ana Trujillo Emparedados y helados', 10308, 69, 'Gudbrandsdalsost', Decimal('36.00'))
# ('Ana Trujillo Emparedados y helados', 10308, 70, 'Outback Lager', Decimal('75.00'))
# ('Antonio Moreno Taquería', 10365, 11, 'Queso Cabrales', Decimal('504.00'))
# ('Around the Horn', 10355, 24, 'Guaraná Fantástica', Decimal('112.50'))
# ('Around the Horn', 10355, 57, 'Ravioli Angelo', Decimal('487.50'))
# ('Around the Horn', 10383, 13, 'Konbu', Decimal('120.00'))
# ('Around the Horn', 10383, 50, 'Valkoinen suklaa', Decimal('243.75'))
# ('Around the Horn', 10383, 56, 'Gnocchi di nonna Alice', Decimal('760.00'))
# ("B's Beverages", 10289, 3, 'Aniseed Syrup', Decimal('300.00'))
# ("B's Beverages", 10289, 64, 'Wimmers gute Semmelknödel', Decimal('299.25'))
# ('Berglunds snabbköp', 10278, 44, 'Gula Malacca', Decimal('311.20'))
# ('Berglunds snabbköp', 10278, 59, 'Raclette Courdavault', Decimal('825.00'))
# ('Berglunds snabbköp', 10278, 63, 'Vegie-spread', Decimal('351.20'))
# ('Berglunds snabbköp', 10278, 73, 'Röd Kaviar', Decimal('375.00'))
# ('Berglunds snabbköp', 10280, 24, 'Guaraná Fantástica', Decimal('54.00'))
# ('Berglunds snabbköp', 10280, 55, 'Pâté chinois', Decimal('480.00'))
# ('Berglunds snabbköp', 10280, 75, 'Rhönbräu Klosterbier', Decimal('232.50'))
# ('Berglunds snabbköp', 10384, 20, "Sir Rodney's Marmalade", Decimal('2268.00'))
# ('Berglunds snabbköp', 10384, 60, 'Camembert Pierrot', Decimal('510.00'))
# ('Blauer See Delikatessen', None, None, None, None)
# ('Blondel père et fils', 10265, 17, 'Alice Mutton', Decimal('1170.00'))
# ('Blondel père et fils', 10265, 70, 'Outback Lager', Decimal('300.00'))
# ('Blondel père et fils', 10297, 39, 'Chartreuse verte', Decimal('1080.00'))
# ('Blondel père et fils', 10297, 72, 'Mozzarella di Giovanni', Decimal('696.00'))
# ('Blondel père et fils', 10360, 28, 'Rössle Sauerkraut', Decimal('1368.00'))
# ('Blondel père et fils', 10360, 29, 'Thüringer Rostbratwurst', Decimal('4332.65'))
# ('Blondel père et fils', 10360, 38, 'Côte de Blaye', Decimal('2635.00'))
# ('Blondel père et fils', 10360, 49, 'Maxilaku', Decimal('700.00'))
# ('Blondel père et fils', 10360, 54, 'Tourtière', Decimal('208.60'))
# ('Blondel père et fils', 10436, 46, 'Spegesild', Decimal('60.00'))
# ('Blondel père et fils', 10436, 56, 'Gnocchi di nonna Alice', Decimal('1520.00'))
# ('Blondel père et fils', 10436, 64, 'Wimmers gute Semmelknödel', Decimal('997.50'))
# ('Blondel père et fils', 10436, 75, 'Rhönbräu Klosterbier', Decimal('186.00'))
# ("Bon app'", 10331, 54, 'Tourtière', Decimal('111.75'))
# ("Bon app'", 10340, 18, 'Carnarvon Tigers', Decimal('1250.00'))
# ("Bon app'", 10340, 41, "Jack's New England Clam Chowder", Decimal('115.80'))
# ("Bon app'", 10340, 43, 'Ipoh Coffee', Decimal('1840.00'))
# ("Bon app'", 10362, 25, 'NuNuCa Nuß-Nougat-Creme', Decimal('700.00'))
# ("Bon app'", 10362, 51, 'Manjimup Dried Apples', Decimal('1060.00'))
# ("Bon app'", 10362, 54, 'Tourtière', Decimal('178.80'))
# ('Bottom-Dollar Marketse', 10389, 10, 'Ikura', Decimal('496.00'))
# ('Bottom-Dollar Marketse', 10389, 55, 'Pâté chinois', Decimal('360.00'))
# ('Bottom-Dollar Marketse', 10389, 62, 'Tarte au sucre', Decimal('986.00'))
# ('Bottom-Dollar Marketse', 10389, 70, 'Outback Lager', Decimal('450.00'))
# ('Bottom-Dollar Marketse', 10410, 33, 'Geitost', Decimal('122.50'))
# ('Bottom-Dollar Marketse', 10410, 59, 'Raclette Courdavault', Decimal('880.00'))
# ('Bottom-Dollar Marketse', 10411, 41, "Jack's New England Clam Chowder", Decimal('241.25'))
# ('Bottom-Dollar Marketse', 10411, 44, 'Gula Malacca', Decimal('778.00'))
# ('Bottom-Dollar Marketse', 10411, 59, 'Raclette Courdavault', Decimal('495.00'))
# ('Bottom-Dollar Marketse', 10431, 17, 'Alice Mutton', Decimal('1950.00'))
# ('Bottom-Dollar Marketse', 10431, 40, 'Boston Crab Meat', Decimal('920.00'))
# ('Bottom-Dollar Marketse', 10431, 47, 'Zaanse koeken', Decimal('285.00'))
# ('Bólido Comidas preparadas', 10326, 4, "Chef Anton's Cajun Seasoning", Decimal('528.00'))
# ('Bólido Comidas preparadas', 10326, 57, 'Ravioli Angelo', Decimal('312.00'))
# ('Bólido Comidas preparadas', 10326, 75, 'Rhönbräu Klosterbier', Decimal('387.50'))
# ('Cactus Comidas para llevar', None, None, None, None)
# ('Centro comercial Moctezuma', 10259, 21, "Sir Rodney's Scones", Decimal('100.00'))
# ('Centro comercial Moctezuma', 10259, 37, 'Gravad lax', Decimal('26.00'))
# ('Chop-suey Chinese', 10254, 24, 'Guaraná Fantástica', Decimal('67.50'))
# ('Chop-suey Chinese', 10254, 55, 'Pâté chinois', Decimal('504.00'))
# ('Chop-suey Chinese', 10254, 74, 'Longlife Tofu', Decimal('210.00'))
# ('Chop-suey Chinese', 10370, 1, 'Chais', Decimal('270.00'))
# ('Chop-suey Chinese', 10370, 64, 'Wimmers gute Semmelknödel', Decimal('997.50'))
# ('Chop-suey Chinese', 10370, 74, 'Longlife Tofu', Decimal('200.00'))
# ('Comércio Mineiro', 10290, 5, "Chef Anton's Gumbo Mix", Decimal('427.00'))
# ('Comércio Mineiro', 10290, 29, 'Thüringer Rostbratwurst', Decimal('1856.85'))
# ('Comércio Mineiro', 10290, 49, 'Maxilaku', Decimal('300.00'))
# ('Comércio Mineiro', 10290, 77, 'Original Frankfurter grüne Soße', Decimal('130.00'))
# ('Consolidated Holdings', 10435, 2, 'Chang', Decimal('190.00'))
# ('Consolidated Holdings', 10435, 22, "Gustaf's Knäckebröd", Decimal('252.00'))
# ('Consolidated Holdings', 10435, 72, 'Mozzarella di Giovanni', Decimal('348.00'))
# ('Die Wandernde Kuh', 10301, 40, 'Boston Crab Meat', Decimal('184.00'))
# ('Die Wandernde Kuh', 10301, 56, 'Gnocchi di nonna Alice', Decimal('760.00'))
# ('Die Wandernde Kuh', 10312, 28, 'Rössle Sauerkraut', Decimal('182.40'))
# ('Die Wandernde Kuh', 10312, 43, 'Ipoh Coffee', Decimal('1104.00'))
# ('Die Wandernde Kuh', 10312, 53, 'Perth Pasties', Decimal('656.00'))
# ('Die Wandernde Kuh', 10312, 75, 'Rhönbräu Klosterbier', Decimal('77.50'))
# ('Die Wandernde Kuh', 10348, 1, 'Chais', Decimal('270.00'))
# ('Die Wandernde Kuh', 10348, 23, 'Tunnbröd', Decimal('225.00'))
# ('Die Wandernde Kuh', 10356, 31, 'Gorgonzola Telino', Decimal('375.00'))
# ('Die Wandernde Kuh', 10356, 55, 'Pâté chinois', Decimal('288.00'))
# ('Die Wandernde Kuh', 10356, 69, 'Gudbrandsdalsost', Decimal('720.00'))
# ('Drachenblut Delikatessend', 10363, 31, 'Gorgonzola Telino', Decimal('250.00'))
# ('Drachenblut Delikatessend', 10363, 75, 'Rhönbräu Klosterbier', Decimal('93.00'))
# ('Drachenblut Delikatessend', 10363, 76, 'Lakkalikööri', Decimal('216.00'))
# ('Drachenblut Delikatessend', 10391, 13, 'Konbu', Decimal('108.00'))
# ('Du monde entier', 10311, 42, 'Singaporean Hokkien Fried Mee', Decimal('84.00'))
# ('Du monde entier', 10311, 69, 'Gudbrandsdalsost', Decimal('252.00'))
# ('Eastern Connection', 10364, 69, 'Gudbrandsdalsost', Decimal('1080.00'))
# ('Eastern Connection', 10364, 71, 'Fløtemysost', Decimal('107.50'))
# ('Eastern Connection', 10400, 29, 'Thüringer Rostbratwurst', Decimal('2599.59'))
# ('Eastern Connection', 10400, 35, 'Steeleye Stout', Decimal('630.00'))
# ('Eastern Connection', 10400, 49, 'Maxilaku', Decimal('600.00'))
# ('Ernst Handel', 10258, 2, 'Chang', Decimal('950.00'))
# ('Ernst Handel', 10258, 5, "Chef Anton's Gumbo Mix", Decimal('1387.75'))
# ('Ernst Handel', 10258, 32, 'Mascarpone Fabioli', Decimal('192.00'))
# ('Ernst Handel', 10263, 16, 'Pavlova', Decimal('1047.00'))
# ('Ernst Handel', 10263, 24, 'Guaraná Fantástica', Decimal('126.00'))
# ('Ernst Handel', 10263, 30, 'Nord-Ost Matjeshering', Decimal('1553.40'))
# ('Ernst Handel', 10263, 74, 'Longlife Tofu', Decimal('360.00'))
# ('Ernst Handel', 10351, 38, 'Côte de Blaye', Decimal('5270.00'))
# ('Ernst Handel', 10351, 41, "Jack's New England Clam Chowder", Decimal('125.45'))
# ('Ernst Handel', 10351, 44, 'Gula Malacca', Decimal('1497.65'))
# ('Ernst Handel', 10351, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('210.50'))
# ('Ernst Handel', 10368, 21, "Sir Rodney's Scones", Decimal('50.00'))
# ('Ernst Handel', 10368, 28, 'Rössle Sauerkraut', Decimal('592.80'))
# ('Ernst Handel', 10368, 57, 'Ravioli Angelo', Decimal('487.50'))
# ('Ernst Handel', 10368, 64, 'Wimmers gute Semmelknödel', Decimal('1163.75'))
# ('Ernst Handel', 10382, 5, "Chef Anton's Gumbo Mix", Decimal('683.20'))
# ('Ernst Handel', 10382, 18, 'Carnarvon Tigers', Decimal('562.50'))
# ('Ernst Handel', 10382, 29, 'Thüringer Rostbratwurst', Decimal('1733.06'))
# ('Ernst Handel', 10382, 33, 'Geitost', Decimal('150.00'))
# ('Ernst Handel', 10382, 74, 'Longlife Tofu', Decimal('500.00'))
# ('Ernst Handel', 10390, 31, 'Gorgonzola Telino', Decimal('750.00'))
# ('Ernst Handel', 10390, 35, 'Steeleye Stout', Decimal('720.00'))
# ('Ernst Handel', 10390, 46, 'Spegesild', Decimal('540.00'))
# ('Ernst Handel', 10390, 72, 'Mozzarella di Giovanni', Decimal('835.20'))
# ('Ernst Handel', 10402, 23, 'Tunnbröd', Decimal('540.00'))
# ('Ernst Handel', 10402, 63, 'Vegie-spread', Decimal('2853.50'))
# ('Ernst Handel', 10403, 16, 'Pavlova', Decimal('366.45'))
# ('Ernst Handel', 10403, 48, 'Chocolade', Decimal('892.50'))
# ('Ernst Handel', 10430, 17, 'Alice Mutton', Decimal('1755.00'))
# ('Ernst Handel', 10430, 21, "Sir Rodney's Scones", Decimal('500.00'))
# ('Ernst Handel', 10430, 56, 'Gnocchi di nonna Alice', Decimal('1140.00'))
# ('Ernst Handel', 10430, 59, 'Raclette Courdavault', Decimal('3850.00'))
# ('Ernst Handel', 10442, 11, 'Queso Cabrales', Decimal('630.00'))
# ('Ernst Handel', 10442, 54, 'Tourtière', Decimal('596.00'))
# ('Ernst Handel', 10442, 66, 'Louisiana Hot Spiced Okra', Decimal('1020.00'))
# ('FISSA Fabrica Inter. Salchichas S.A.', None, None, None, None)
# ('Familia Arquibaldo', 10347, 25, 'NuNuCa Nuß-Nougat-Creme', Decimal('140.00'))
# ('Familia Arquibaldo', 10347, 39, 'Chartreuse verte', Decimal('900.00'))
# ('Familia Arquibaldo', 10347, 40, 'Boston Crab Meat', Decimal('73.60'))
# ('Familia Arquibaldo', 10347, 75, 'Rhönbräu Klosterbier', Decimal('46.50'))
# ('Familia Arquibaldo', 10386, 24, 'Guaraná Fantástica', Decimal('67.50'))
# ('Familia Arquibaldo', 10386, 34, 'Sasquatch Ale', Decimal('140.00'))
# ('Familia Arquibaldo', 10414, 19, 'Teatime Chocolate Biscuits', Decimal('165.60'))
# ('Familia Arquibaldo', 10414, 33, 'Geitost', Decimal('125.00'))
# ('Folies gourmandes', 10408, 37, 'Gravad lax', Decimal('260.00'))
# ('Folies gourmandes', 10408, 54, 'Tourtière', Decimal('44.70'))
# ('Folies gourmandes', 10408, 62, 'Tarte au sucre', Decimal('1725.50'))
# ('Folk och fä HB', 10264, 2, 'Chang', Decimal('665.00'))
# ('Folk och fä HB', 10264, 41, "Jack's New England Clam Chowder", Decimal('241.25'))
# ('Folk och fä HB', 10327, 2, 'Chang', Decimal('475.00'))
# ('Folk och fä HB', 10327, 11, 'Queso Cabrales', Decimal('1050.00'))
# ('Folk och fä HB', 10327, 30, 'Nord-Ost Matjeshering', Decimal('906.15'))
# ('Folk och fä HB', 10327, 58, 'Escargots de Bourgogne', Decimal('397.50'))
# ('Folk och fä HB', 10378, 71, 'Fløtemysost', Decimal('129.00'))
# ('Folk och fä HB', 10434, 11, 'Queso Cabrales', Decimal('126.00'))
# ('Folk och fä HB', 10434, 76, 'Lakkalikööri', Decimal('324.00'))
# ('France restauration', None, None, None, None)
# ('Franchi S.p.A.', 10422, 26, 'Gumbär Gummibärchen', Decimal('62.46'))
# ('Frankenversand', 10267, 40, 'Boston Crab Meat', Decimal('920.00'))
# ('Frankenversand', 10267, 59, 'Raclette Courdavault', Decimal('3850.00'))
# ('Frankenversand', 10267, 76, 'Lakkalikööri', Decimal('270.00'))
# ('Frankenversand', 10337, 23, 'Tunnbröd', Decimal('360.00'))
# ('Frankenversand', 10337, 26, 'Gumbär Gummibärchen', Decimal('749.52'))
# ('Frankenversand', 10337, 36, 'Inlagd Sill', Decimal('380.00'))
# ('Frankenversand', 10337, 37, 'Gravad lax', Decimal('728.00'))
# ('Frankenversand', 10337, 72, 'Mozzarella di Giovanni', Decimal('870.00'))
# ('Frankenversand', 10342, 2, 'Chang', Decimal('456.00'))
# ('Frankenversand', 10342, 31, 'Gorgonzola Telino', Decimal('700.00'))
# ('Frankenversand', 10342, 36, 'Inlagd Sill', Decimal('760.00'))
# ('Frankenversand', 10342, 55, 'Pâté chinois', Decimal('960.00'))
# ('Frankenversand', 10396, 23, 'Tunnbröd', Decimal('360.00'))
# ('Frankenversand', 10396, 71, 'Fløtemysost', Decimal('1290.00'))
# ('Frankenversand', 10396, 72, 'Mozzarella di Giovanni', Decimal('730.80'))
# ('Furia Bacalhau e Frutos do Mar', 10328, 59, 'Raclette Courdavault', Decimal('495.00'))
# ('Furia Bacalhau e Frutos do Mar', 10328, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('842.00'))
# ('Furia Bacalhau e Frutos do Mar', 10328, 68, 'Scottish Longbreads', Decimal('125.00'))
# ('Furia Bacalhau e Frutos do Mar', 10352, 24, 'Guaraná Fantástica', Decimal('45.00'))
# ('Furia Bacalhau e Frutos do Mar', 10352, 54, 'Tourtière', Decimal('149.00'))
# ('GROSELLA-Restaurante', 10268, 29, 'Thüringer Rostbratwurst', Decimal('1237.90'))
# ('GROSELLA-Restaurante', 10268, 72, 'Mozzarella di Giovanni', Decimal('139.20'))
# ('Galería del gastrónomo', 10366, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('105.25'))
# ('Galería del gastrónomo', 10366, 77, 'Original Frankfurter grüne Soße', Decimal('65.00'))
# ('Galería del gastrónomo', 10426, 56, 'Gnocchi di nonna Alice', Decimal('190.00'))
# ('Galería del gastrónomo', 10426, 64, 'Wimmers gute Semmelknödel', Decimal('232.75'))
# ('Godos Cocina Típica', 10303, 40, 'Boston Crab Meat', Decimal('736.00'))
# ('Godos Cocina Típica', 10303, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('631.50'))
# ('Godos Cocina Típica', 10303, 68, 'Scottish Longbreads', Decimal('187.50'))
# ('Gourmet Lanchonetes', 10423, 31, 'Gorgonzola Telino', Decimal('175.00'))
# ('Gourmet Lanchonetes', 10423, 59, 'Raclette Courdavault', Decimal('1100.00'))
# ('Great Lakes Food Market', None, None, None, None)
# ('HILARIÓN-Abastos', 10257, 27, 'Schoggi Schokolade', Decimal('1097.50'))
# ('HILARIÓN-Abastos', 10257, 39, 'Chartreuse verte', Decimal('108.00'))
# ('HILARIÓN-Abastos', 10257, 77, 'Original Frankfurter grüne Soße', Decimal('195.00'))
# ('HILARIÓN-Abastos', 10395, 46, 'Spegesild', Decimal('336.00'))
# ('HILARIÓN-Abastos', 10395, 53, 'Perth Pasties', Decimal('2296.00'))
# ('HILARIÓN-Abastos', 10395, 69, 'Gudbrandsdalsost', Decimal('288.00'))
# ('Hanari Carnes', 10250, 41, "Jack's New England Clam Chowder", Decimal('96.50'))
# ('Hanari Carnes', 10250, 51, 'Manjimup Dried Apples', Decimal('1855.00'))
# ('Hanari Carnes', 10250, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('315.75'))
# ('Hanari Carnes', 10253, 31, 'Gorgonzola Telino', Decimal('250.00'))
# ('Hanari Carnes', 10253, 39, 'Chartreuse verte', Decimal('756.00'))
# ('Hanari Carnes', 10253, 49, 'Maxilaku', Decimal('800.00'))
# ('Hungry Coyote Import Store', 10375, 14, 'Tofu', Decimal('348.75'))
# ('Hungry Coyote Import Store', 10375, 54, 'Tourtière', Decimal('74.50'))
# ('Hungry Coyote Import Store', 10394, 13, 'Konbu', Decimal('60.00'))
# ('Hungry Coyote Import Store', 10394, 62, 'Tarte au sucre', Decimal('493.00'))
# ('Hungry Coyote Import Store', 10415, 17, 'Alice Mutton', Decimal('78.00'))
# ('Hungry Coyote Import Store', 10415, 33, 'Geitost', Decimal('50.00'))
# ('Hungry Owl All-Night Grocers', 10298, 2, 'Chang', Decimal('760.00'))
# ('Hungry Owl All-Night Grocers', 10298, 36, 'Inlagd Sill', Decimal('760.00'))
# ('Hungry Owl All-Night Grocers', 10298, 59, 'Raclette Courdavault', Decimal('1650.00'))
# ('Hungry Owl All-Night Grocers', 10298, 62, 'Tarte au sucre', Decimal('739.50'))
# ('Hungry Owl All-Night Grocers', 10309, 4, "Chef Anton's Cajun Seasoning", Decimal('440.00'))
# ('Hungry Owl All-Night Grocers', 10309, 6, "Grandma's Boysenberry Spread", Decimal('750.00'))
# ('Hungry Owl All-Night Grocers', 10309, 42, 'Singaporean Hokkien Fried Mee', Decimal('28.00'))
# ('Hungry Owl All-Night Grocers', 10309, 43, 'Ipoh Coffee', Decimal('920.00'))
# ('Hungry Owl All-Night Grocers', 10309, 71, 'Fløtemysost', Decimal('64.50'))
# ('Hungry Owl All-Night Grocers', 10335, 2, 'Chang', Decimal('133.00'))
# ('Hungry Owl All-Night Grocers', 10335, 31, 'Gorgonzola Telino', Decimal('312.50'))
# ('Hungry Owl All-Night Grocers', 10335, 32, 'Mascarpone Fabioli', Decimal('192.00'))
# ('Hungry Owl All-Night Grocers', 10335, 51, 'Manjimup Dried Apples', Decimal('2544.00'))
# ('Hungry Owl All-Night Grocers', 10373, 58, 'Escargots de Bourgogne', Decimal('1060.00'))
# ('Hungry Owl All-Night Grocers', 10373, 71, 'Fløtemysost', Decimal('1075.00'))
# ('Hungry Owl All-Night Grocers', 10380, 30, 'Nord-Ost Matjeshering', Decimal('466.02'))
# ('Hungry Owl All-Night Grocers', 10380, 53, 'Perth Pasties', Decimal('656.00'))
# ('Hungry Owl All-Night Grocers', 10380, 60, 'Camembert Pierrot', Decimal('204.00'))
# ('Hungry Owl All-Night Grocers', 10380, 70, 'Outback Lager', Decimal('450.00'))
# ('Hungry Owl All-Night Grocers', 10429, 50, 'Valkoinen suklaa', Decimal('650.00'))
# ('Hungry Owl All-Night Grocers', 10429, 63, 'Vegie-spread', Decimal('1536.50'))
# ('Island Trading', 10315, 34, 'Sasquatch Ale', Decimal('196.00'))
# ('Island Trading', 10315, 70, 'Outback Lager', Decimal('450.00'))
# ('Island Trading', 10318, 41, "Jack's New England Clam Chowder", Decimal('193.00'))
# ('Island Trading', 10318, 76, 'Lakkalikööri', Decimal('108.00'))
# ('Island Trading', 10321, 35, 'Steeleye Stout', Decimal('180.00'))
# ('Königlich Essen', 10323, 15, 'Genen Shouyu', Decimal('77.50'))
# ('Königlich Essen', 10323, 25, 'NuNuCa Nuß-Nougat-Creme', Decimal('56.00'))
# ('Königlich Essen', 10323, 39, 'Chartreuse verte', Decimal('72.00'))
# ('Königlich Essen', 10325, 6, "Grandma's Boysenberry Spread", Decimal('150.00'))
# ('Königlich Essen', 10325, 13, 'Konbu', Decimal('72.00'))
# ('Königlich Essen', 10325, 14, 'Tofu', Decimal('209.25'))
# ('Königlich Essen', 10325, 31, 'Gorgonzola Telino', Decimal('50.00'))
# ('Königlich Essen', 10325, 72, 'Mozzarella di Giovanni', Decimal('1392.00'))
# ('LILA-Supermercado', 10283, 15, 'Genen Shouyu', Decimal('310.00'))
# ('LILA-Supermercado', 10283, 19, 'Teatime Chocolate Biscuits', Decimal('165.60'))
# ('LILA-Supermercado', 10283, 60, 'Camembert Pierrot', Decimal('1190.00'))
# ('LILA-Supermercado', 10283, 72, 'Mozzarella di Giovanni', Decimal('104.40'))
# ('LILA-Supermercado', 10296, 11, 'Queso Cabrales', Decimal('252.00'))
# ('LILA-Supermercado', 10296, 16, 'Pavlova', Decimal('523.50'))
# ('LILA-Supermercado', 10296, 69, 'Gudbrandsdalsost', Decimal('540.00'))
# ('LILA-Supermercado', 10330, 26, 'Gumbär Gummibärchen', Decimal('1561.50'))
# ('LILA-Supermercado', 10330, 72, 'Mozzarella di Giovanni', Decimal('870.00'))
# ('LILA-Supermercado', 10357, 10, 'Ikura', Decimal('930.00'))
# ('LILA-Supermercado', 10357, 26, 'Gumbär Gummibärchen', Decimal('499.68'))
# ('LILA-Supermercado', 10357, 60, 'Camembert Pierrot', Decimal('272.00'))
# ('LILA-Supermercado', 10381, 74, 'Longlife Tofu', Decimal('140.00'))
# ('LINO-Delicateses', 10405, 3, 'Aniseed Syrup', Decimal('500.00'))
# ("La corne d'abondance", None, None, None, None)
# ("La maison d'Asie", 10350, 50, 'Valkoinen suklaa', Decimal('243.75'))
# ("La maison d'Asie", 10350, 69, 'Gudbrandsdalsost', Decimal('648.00'))
# ("La maison d'Asie", 10358, 24, 'Guaraná Fantástica', Decimal('45.00'))
# ("La maison d'Asie", 10358, 34, 'Sasquatch Ale', Decimal('140.00'))
# ("La maison d'Asie", 10358, 36, 'Inlagd Sill', Decimal('380.00'))
# ("La maison d'Asie", 10371, 36, 'Inlagd Sill', Decimal('114.00'))
# ("La maison d'Asie", 10413, 1, 'Chais', Decimal('432.00'))
# ("La maison d'Asie", 10413, 62, 'Tarte au sucre', Decimal('1972.00'))
# ("La maison d'Asie", 10413, 76, 'Lakkalikööri', Decimal('252.00'))
# ("La maison d'Asie", 10425, 55, 'Pâté chinois', Decimal('240.00'))
# ("La maison d'Asie", 10425, 76, 'Lakkalikööri', Decimal('360.00'))
# ('Laughing Bacchus Wine Cellars', None, None, None, None)
# ('Lazy K Kountry Store', None, None, None, None)
# ('Lehmanns Marktstand', 10279, 17, 'Alice Mutton', Decimal('585.00'))
# ('Lehmanns Marktstand', 10284, 27, 'Schoggi Schokolade', Decimal('658.50'))
# ('Lehmanns Marktstand', 10284, 44, 'Gula Malacca', Decimal('408.45'))
# ('Lehmanns Marktstand', 10284, 60, 'Camembert Pierrot', Decimal('680.00'))
# ('Lehmanns Marktstand', 10284, 67, 'Laughing Lumberjack Lager', Decimal('70.00'))
# ('Lehmanns Marktstand', 10343, 64, 'Wimmers gute Semmelknödel', Decimal('1662.50'))
# ('Lehmanns Marktstand', 10343, 68, 'Scottish Longbreads', Decimal('50.00'))
# ('Lehmanns Marktstand', 10343, 76, 'Lakkalikööri', Decimal('270.00'))
# ("Let's Stop N Shop", None, None, None, None)
# ('Lonesome Pine Restaurant', 10307, 62, 'Tarte au sucre', Decimal('493.00'))
# ('Lonesome Pine Restaurant', 10307, 68, 'Scottish Longbreads', Decimal('37.50'))
# ('Lonesome Pine Restaurant', 10317, 1, 'Chais', Decimal('360.00'))
# ('Magazzini Alimentari Riuniti', 10275, 24, 'Guaraná Fantástica', Decimal('54.00'))
# ('Magazzini Alimentari Riuniti', 10275, 59, 'Raclette Courdavault', Decimal('330.00'))
# ('Magazzini Alimentari Riuniti', 10300, 66, 'Louisiana Hot Spiced Okra', Decimal('510.00'))
# ('Magazzini Alimentari Riuniti', 10300, 68, 'Scottish Longbreads', Decimal('250.00'))
# ('Magazzini Alimentari Riuniti', 10404, 26, 'Gumbär Gummibärchen', Decimal('936.90'))
# ('Magazzini Alimentari Riuniti', 10404, 42, 'Singaporean Hokkien Fried Mee', Decimal('560.00'))
# ('Magazzini Alimentari Riuniti', 10404, 49, 'Maxilaku', Decimal('600.00'))
# ('Maison Dewey', None, None, None, None)
# ('Morgenstern Gesundkost', 10277, 28, 'Rössle Sauerkraut', Decimal('912.00'))
# ('Morgenstern Gesundkost', 10277, 62, 'Tarte au sucre', Decimal('591.60'))
# ('Mère Paillarde', 10332, 18, 'Carnarvon Tigers', Decimal('2500.00'))
# ('Mère Paillarde', 10332, 42, 'Singaporean Hokkien Fried Mee', Decimal('140.00'))
# ('Mère Paillarde', 10332, 47, 'Zaanse koeken', Decimal('152.00'))
# ('Mère Paillarde', 10339, 4, "Chef Anton's Cajun Seasoning", Decimal('220.00'))
# ('Mère Paillarde', 10339, 17, 'Alice Mutton', Decimal('2730.00'))
# ('Mère Paillarde', 10339, 62, 'Tarte au sucre', Decimal('1380.40'))
# ('Mère Paillarde', 10376, 31, 'Gorgonzola Telino', Decimal('525.00'))
# ('Mère Paillarde', 10424, 35, 'Steeleye Stout', Decimal('1080.00'))
# ('Mère Paillarde', 10424, 38, 'Côte de Blaye', Decimal('12911.50'))
# ('Mère Paillarde', 10424, 68, 'Scottish Longbreads', Decimal('375.00'))
# ('Mère Paillarde', 10439, 12, 'Queso Manchego La Pastora', Decimal('570.00'))
# ('Mère Paillarde', 10439, 16, 'Pavlova', Decimal('279.20'))
# ('Mère Paillarde', 10439, 64, 'Wimmers gute Semmelknödel', Decimal('199.50'))
# ('Mère Paillarde', 10439, 74, 'Longlife Tofu', Decimal('300.00'))
# ('North/South', None, None, None, None)
# ('Océano Atlántico Ltda.', 10409, 14, 'Tofu', Decimal('279.00'))
# ('Océano Atlántico Ltda.', 10409, 21, "Sir Rodney's Scones", Decimal('120.00'))
# ('Old World Delicatessen', 10260, 41, "Jack's New England Clam Chowder", Decimal('154.40'))
# ('Old World Delicatessen', 10260, 57, 'Ravioli Angelo', Decimal('975.00'))
# ('Old World Delicatessen', 10260, 62, 'Tarte au sucre', Decimal('739.50'))
# ('Old World Delicatessen', 10260, 70, 'Outback Lager', Decimal('315.00'))
# ('Old World Delicatessen', 10305, 18, 'Carnarvon Tigers', Decimal('1562.50'))
# ('Old World Delicatessen', 10305, 29, 'Thüringer Rostbratwurst', Decimal('3094.75'))
# ('Old World Delicatessen', 10305, 39, 'Chartreuse verte', Decimal('540.00'))
# ('Old World Delicatessen', 10338, 17, 'Alice Mutton', Decimal('780.00'))
# ('Old World Delicatessen', 10338, 30, 'Nord-Ost Matjeshering', Decimal('388.35'))
# ('Old World Delicatessen', 10441, 27, 'Schoggi Schokolade', Decimal('2195.00'))
# ('Ottilies Käseladen', 10407, 11, 'Queso Cabrales', Decimal('630.00'))
# ('Ottilies Käseladen', 10407, 69, 'Gudbrandsdalsost', Decimal('540.00'))
# ('Ottilies Käseladen', 10407, 71, 'Fløtemysost', Decimal('322.50'))
# ('Paris spécialités', None, None, None, None)
# ('Pericles Comidas clásicas', 10322, 52, 'Filo Mix', Decimal('140.00'))
# ('Pericles Comidas clásicas', 10354, 1, 'Chais', Decimal('216.00'))
# ('Pericles Comidas clásicas', 10354, 29, 'Thüringer Rostbratwurst', Decimal('495.16'))
# ('Piccolo und mehr', 10353, 11, 'Queso Cabrales', Decimal('252.00'))
# ('Piccolo und mehr', 10353, 38, 'Côte de Blaye', Decimal('13175.00'))
# ('Piccolo und mehr', 10392, 69, 'Gudbrandsdalsost', Decimal('1800.00'))
# ('Piccolo und mehr', 10427, 14, 'Tofu', Decimal('813.75'))
# ('Princesa Isabel Vinhoss', 10336, 4, "Chef Anton's Cajun Seasoning", Decimal('396.00'))
# ('Princesa Isabel Vinhoss', 10397, 21, "Sir Rodney's Scones", Decimal('100.00'))
# ('Princesa Isabel Vinhoss', 10397, 51, 'Manjimup Dried Apples', Decimal('954.00'))
# ('Princesa Isabel Vinhoss', 10433, 56, 'Gnocchi di nonna Alice', Decimal('1064.00'))
# ('QUICK-Stop', 10273, 10, 'Ikura', Decimal('744.00'))
# ('QUICK-Stop', 10273, 31, 'Gorgonzola Telino', Decimal('187.50'))
# ('QUICK-Stop', 10273, 33, 'Geitost', Decimal('50.00'))
# ('QUICK-Stop', 10273, 40, 'Boston Crab Meat', Decimal('1104.00'))
# ('QUICK-Stop', 10273, 76, 'Lakkalikööri', Decimal('594.00'))
# ('QUICK-Stop', 10285, 1, 'Chais', Decimal('810.00'))
# ('QUICK-Stop', 10285, 40, 'Boston Crab Meat', Decimal('736.00'))
# ('QUICK-Stop', 10285, 53, 'Perth Pasties', Decimal('1180.80'))
# ('QUICK-Stop', 10286, 35, 'Steeleye Stout', Decimal('1800.00'))
# ('QUICK-Stop', 10286, 62, 'Tarte au sucre', Decimal('1972.00'))
# ('QUICK-Stop', 10313, 36, 'Inlagd Sill', Decimal('228.00'))
# ('QUICK-Stop', 10345, 8, 'Northwoods Cranberry Sauce', Decimal('2800.00'))
# ('QUICK-Stop', 10345, 19, 'Teatime Chocolate Biscuits', Decimal('736.00'))
# ('QUICK-Stop', 10345, 42, 'Singaporean Hokkien Fried Mee', Decimal('126.00'))
# ('QUICK-Stop', 10361, 39, 'Chartreuse verte', Decimal('972.00'))
# ('QUICK-Stop', 10361, 60, 'Camembert Pierrot', Decimal('1870.00'))
# ('QUICK-Stop', 10418, 2, 'Chang', Decimal('1140.00'))
# ('QUICK-Stop', 10418, 47, 'Zaanse koeken', Decimal('522.50'))
# ('QUICK-Stop', 10418, 61, "Sirop d'érable", Decimal('456.00'))
# ('QUICK-Stop', 10418, 74, 'Longlife Tofu', Decimal('150.00'))
# ('Que Delícia', 10261, 21, "Sir Rodney's Scones", Decimal('200.00'))
# ('Que Delícia', 10261, 35, 'Steeleye Stout', Decimal('360.00'))
# ('Que Delícia', 10291, 13, 'Konbu', Decimal('120.00'))
# ('Que Delícia', 10291, 44, 'Gula Malacca', Decimal('466.80'))
# ('Que Delícia', 10291, 51, 'Manjimup Dried Apples', Decimal('106.00'))
# ('Que Delícia', 10379, 41, "Jack's New England Clam Chowder", Decimal('77.20'))
# ('Que Delícia', 10379, 63, 'Vegie-spread', Decimal('702.40'))
# ('Que Delícia', 10379, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('421.00'))
# ('Que Delícia', 10421, 19, 'Teatime Chocolate Biscuits', Decimal('36.80'))
# ('Que Delícia', 10421, 26, 'Gumbär Gummibärchen', Decimal('936.90'))
# ('Que Delícia', 10421, 53, 'Perth Pasties', Decimal('492.00'))
# ('Que Delícia', 10421, 77, 'Original Frankfurter grüne Soße', Decimal('130.00'))
# ('Queen Cozinha', 10372, 20, "Sir Rodney's Marmalade", Decimal('972.00'))
# ('Queen Cozinha', 10372, 38, 'Côte de Blaye', Decimal('10540.00'))
# ('Queen Cozinha', 10372, 60, 'Camembert Pierrot', Decimal('2380.00'))
# ('Queen Cozinha', 10372, 72, 'Mozzarella di Giovanni', Decimal('1461.60'))
# ('Queen Cozinha', 10406, 1, 'Chais', Decimal('180.00'))
# ('Queen Cozinha', 10406, 21, "Sir Rodney's Scones", Decimal('300.00'))
# ('Queen Cozinha', 10406, 28, 'Rössle Sauerkraut', Decimal('1915.20'))
# ('Queen Cozinha', 10406, 36, 'Inlagd Sill', Decimal('95.00'))
# ('Queen Cozinha', 10406, 40, 'Boston Crab Meat', Decimal('36.80'))
# ('Rancho grande', None, None, None, None)
# ('Rattlesnake Canyon Grocery', 10262, 5, "Chef Anton's Gumbo Mix", Decimal('256.20'))
# ('Rattlesnake Canyon Grocery', 10262, 7, "Uncle Bob's Organic Dried Pears", Decimal('450.00'))
# ('Rattlesnake Canyon Grocery', 10262, 56, 'Gnocchi di nonna Alice', Decimal('76.00'))
# ('Rattlesnake Canyon Grocery', 10272, 20, "Sir Rodney's Marmalade", Decimal('486.00'))
# ('Rattlesnake Canyon Grocery', 10272, 31, 'Gorgonzola Telino', Decimal('500.00'))
# ('Rattlesnake Canyon Grocery', 10272, 72, 'Mozzarella di Giovanni', Decimal('835.20'))
# ('Rattlesnake Canyon Grocery', 10294, 1, 'Chais', Decimal('324.00'))
# ('Rattlesnake Canyon Grocery', 10294, 17, 'Alice Mutton', Decimal('585.00'))
# ('Rattlesnake Canyon Grocery', 10294, 43, 'Ipoh Coffee', Decimal('690.00'))
# ('Rattlesnake Canyon Grocery', 10294, 60, 'Camembert Pierrot', Decimal('714.00'))
# ('Rattlesnake Canyon Grocery', 10294, 75, 'Rhönbräu Klosterbier', Decimal('46.50'))
# ('Rattlesnake Canyon Grocery', 10314, 32, 'Mascarpone Fabioli', Decimal('1280.00'))
# ('Rattlesnake Canyon Grocery', 10314, 58, 'Escargots de Bourgogne', Decimal('397.50'))
# ('Rattlesnake Canyon Grocery', 10314, 62, 'Tarte au sucre', Decimal('1232.50'))
# ('Rattlesnake Canyon Grocery', 10316, 41, "Jack's New England Clam Chowder", Decimal('96.50'))
# ('Rattlesnake Canyon Grocery', 10316, 62, 'Tarte au sucre', Decimal('3451.00'))
# ('Rattlesnake Canyon Grocery', 10346, 17, 'Alice Mutton', Decimal('1404.00'))
# ('Rattlesnake Canyon Grocery', 10346, 56, 'Gnocchi di nonna Alice', Decimal('760.00'))
# ('Rattlesnake Canyon Grocery', 10401, 30, 'Nord-Ost Matjeshering', Decimal('466.02'))
# ('Rattlesnake Canyon Grocery', 10401, 56, 'Gnocchi di nonna Alice', Decimal('2660.00'))
# ('Rattlesnake Canyon Grocery', 10401, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('421.00'))
# ('Rattlesnake Canyon Grocery', 10401, 71, 'Fløtemysost', Decimal('1290.00'))
# ('Reggiani Caseifici', 10288, 54, 'Tourtière', Decimal('74.50'))
# ('Reggiani Caseifici', 10288, 68, 'Scottish Longbreads', Decimal('37.50'))
# ('Reggiani Caseifici', 10428, 46, 'Spegesild', Decimal('240.00'))
# ('Reggiani Caseifici', 10443, 11, 'Queso Cabrales', Decimal('126.00'))
# ('Reggiani Caseifici', 10443, 28, 'Rössle Sauerkraut', Decimal('547.20'))
# ('Ricardo Adocicados', 10287, 16, 'Pavlova', Decimal('698.00'))
# ('Ricardo Adocicados', 10287, 34, 'Sasquatch Ale', Decimal('280.00'))
# ('Ricardo Adocicados', 10287, 46, 'Spegesild', Decimal('180.00'))
# ('Ricardo Adocicados', 10299, 19, 'Teatime Chocolate Biscuits', Decimal('138.00'))
# ('Ricardo Adocicados', 10299, 70, 'Outback Lager', Decimal('300.00'))
# ('Richter Supermarkt', 10255, 2, 'Chang', Decimal('380.00'))
# ('Richter Supermarkt', 10255, 16, 'Pavlova', Decimal('610.75'))
# ('Richter Supermarkt', 10255, 36, 'Inlagd Sill', Decimal('475.00'))
# ('Richter Supermarkt', 10255, 59, 'Raclette Courdavault', Decimal('1650.00'))
# ('Richter Supermarkt', 10419, 60, 'Camembert Pierrot', Decimal('2040.00'))
# ('Richter Supermarkt', 10419, 69, 'Gudbrandsdalsost', Decimal('720.00'))
# ('Romero y tomillo', 10281, 19, 'Teatime Chocolate Biscuits', Decimal('9.20'))
# ('Romero y tomillo', 10281, 24, 'Guaraná Fantástica', Decimal('27.00'))
# ('Romero y tomillo', 10281, 35, 'Steeleye Stout', Decimal('72.00'))
# ('Romero y tomillo', 10282, 30, 'Nord-Ost Matjeshering', Decimal('155.34'))
# ('Romero y tomillo', 10282, 57, 'Ravioli Angelo', Decimal('39.00'))
# ('Romero y tomillo', 10306, 30, 'Nord-Ost Matjeshering', Decimal('258.90'))
# ('Romero y tomillo', 10306, 53, 'Perth Pasties', Decimal('328.00'))
# ('Romero y tomillo', 10306, 54, 'Tourtière', Decimal('37.25'))
# ('Santé Gourmet', 10387, 24, 'Guaraná Fantástica', Decimal('67.50'))
# ('Santé Gourmet', 10387, 28, 'Rössle Sauerkraut', Decimal('273.60'))
# ('Santé Gourmet', 10387, 59, 'Raclette Courdavault', Decimal('660.00'))
# ('Santé Gourmet', 10387, 71, 'Fløtemysost', Decimal('322.50'))
# ('Save-a-lot Markets', 10324, 16, 'Pavlova', Decimal('366.45'))
# ('Save-a-lot Markets', 10324, 35, 'Steeleye Stout', Decimal('1260.00'))
# ('Save-a-lot Markets', 10324, 46, 'Spegesild', Decimal('360.00'))
# ('Save-a-lot Markets', 10324, 59, 'Raclette Courdavault', Decimal('2200.00'))
# ('Save-a-lot Markets', 10324, 63, 'Vegie-spread', Decimal('3512.00'))
# ('Save-a-lot Markets', 10393, 2, 'Chang', Decimal('475.00'))
# ('Save-a-lot Markets', 10393, 14, 'Tofu', Decimal('976.50'))
# ('Save-a-lot Markets', 10393, 25, 'NuNuCa Nuß-Nougat-Creme', Decimal('98.00'))
# ('Save-a-lot Markets', 10393, 26, 'Gumbär Gummibärchen', Decimal('2186.10'))
# ('Save-a-lot Markets', 10393, 31, 'Gorgonzola Telino', Decimal('400.00'))
# ('Save-a-lot Markets', 10398, 35, 'Steeleye Stout', Decimal('540.00'))
# ('Save-a-lot Markets', 10398, 55, 'Pâté chinois', Decimal('2880.00'))
# ('Save-a-lot Markets', 10440, 2, 'Chang', Decimal('855.00'))
# ('Save-a-lot Markets', 10440, 16, 'Pavlova', Decimal('855.05'))
# ('Save-a-lot Markets', 10440, 29, 'Thüringer Rostbratwurst', Decimal('2970.96'))
# ('Save-a-lot Markets', 10440, 61, "Sirop d'érable", Decimal('2565.00'))
# ('Seven Seas Imports', 10359, 16, 'Pavlova', Decimal('977.20'))
# ('Seven Seas Imports', 10359, 31, 'Gorgonzola Telino', Decimal('875.00'))
# ('Seven Seas Imports', 10359, 60, 'Camembert Pierrot', Decimal('2720.00'))
# ('Seven Seas Imports', 10377, 28, 'Rössle Sauerkraut', Decimal('912.00'))
# ('Seven Seas Imports', 10377, 39, 'Chartreuse verte', Decimal('360.00'))
# ('Seven Seas Imports', 10388, 45, 'Røgede sild', Decimal('142.50'))
# ('Seven Seas Imports', 10388, 52, 'Filo Mix', Decimal('140.00'))
# ('Seven Seas Imports', 10388, 53, 'Perth Pasties', Decimal('1312.00'))
# ('Simons bistro', 10341, 33, 'Geitost', Decimal('20.00'))
# ('Simons bistro', 10341, 59, 'Raclette Courdavault', Decimal('495.00'))
# ('Simons bistro', 10417, 38, 'Côte de Blaye', Decimal('13175.00'))
# ('Simons bistro', 10417, 46, 'Spegesild', Decimal('24.00'))
# ('Simons bistro', 10417, 68, 'Scottish Longbreads', Decimal('450.00'))
# ('Simons bistro', 10417, 77, 'Original Frankfurter grüne Soße', Decimal('455.00'))
# ('Split Rail Beer & Ale', 10271, 33, 'Geitost', Decimal('60.00'))
# ('Split Rail Beer & Ale', 10329, 19, 'Teatime Chocolate Biscuits', Decimal('92.00'))
# ('Split Rail Beer & Ale', 10329, 30, 'Nord-Ost Matjeshering', Decimal('207.12'))
# ('Split Rail Beer & Ale', 10329, 38, 'Côte de Blaye', Decimal('5270.00'))
# ('Split Rail Beer & Ale', 10329, 56, 'Gnocchi di nonna Alice', Decimal('456.00'))
# ('Split Rail Beer & Ale', 10349, 54, 'Tourtière', Decimal('178.80'))
# ('Split Rail Beer & Ale', 10369, 29, 'Thüringer Rostbratwurst', Decimal('2475.80'))
# ('Split Rail Beer & Ale', 10369, 56, 'Gnocchi di nonna Alice', Decimal('684.00'))
# ('Split Rail Beer & Ale', 10385, 7, "Uncle Bob's Organic Dried Pears", Decimal('300.00'))
# ('Split Rail Beer & Ale', 10385, 60, 'Camembert Pierrot', Decimal('680.00'))
# ('Split Rail Beer & Ale', 10385, 68, 'Scottish Longbreads', Decimal('100.00'))
# ('Split Rail Beer & Ale', 10432, 26, 'Gumbär Gummibärchen', Decimal('312.30'))
# ('Split Rail Beer & Ale', 10432, 54, 'Tourtière', Decimal('298.00'))
# ('Spécialités du monde', None, None, None, None)
# ('Suprêmes délices', 10252, 20, "Sir Rodney's Marmalade", Decimal('3240.00'))
# ('Suprêmes délices', 10252, 33, 'Geitost', Decimal('62.50'))
# ('Suprêmes délices', 10252, 60, 'Camembert Pierrot', Decimal('1360.00'))
# ('Suprêmes délices', 10302, 17, 'Alice Mutton', Decimal('1560.00'))
# ('Suprêmes délices', 10302, 28, 'Rössle Sauerkraut', Decimal('1276.80'))
# ('Suprêmes délices', 10302, 43, 'Ipoh Coffee', Decimal('552.00'))
# ('The Big Cheese', 10310, 16, 'Pavlova', Decimal('174.50'))
# ('The Big Cheese', 10310, 62, 'Tarte au sucre', Decimal('246.50'))
# ('The Cracker Box', None, None, None, None)
# ('Toms Spezialitäten', 10438, 19, 'Teatime Chocolate Biscuits', Decimal('138.00'))
# ('Toms Spezialitäten', 10438, 34, 'Sasquatch Ale', Decimal('280.00'))
# ('Toms Spezialitäten', 10438, 57, 'Ravioli Angelo', Decimal('292.50'))
# ('Tortuga Restaurante', 10276, 10, 'Ikura', Decimal('465.00'))
# ('Tortuga Restaurante', 10276, 13, 'Konbu', Decimal('60.00'))
# ('Tortuga Restaurante', 10293, 18, 'Carnarvon Tigers', Decimal('750.00'))
# ('Tortuga Restaurante', 10293, 24, 'Guaraná Fantástica', Decimal('45.00'))
# ('Tortuga Restaurante', 10293, 63, 'Vegie-spread', Decimal('219.50'))
# ('Tortuga Restaurante', 10293, 75, 'Rhönbräu Klosterbier', Decimal('46.50'))
# ('Tortuga Restaurante', 10304, 49, 'Maxilaku', Decimal('600.00'))
# ('Tortuga Restaurante', 10304, 59, 'Raclette Courdavault', Decimal('550.00'))
# ('Tortuga Restaurante', 10304, 71, 'Fløtemysost', Decimal('43.00'))
# ('Tortuga Restaurante', 10319, 17, 'Alice Mutton', Decimal('312.00'))
# ('Tortuga Restaurante', 10319, 28, 'Rössle Sauerkraut', Decimal('638.40'))
# ('Tortuga Restaurante', 10319, 76, 'Lakkalikööri', Decimal('540.00'))
# ('Tradição Hipermercados', 10249, 14, 'Tofu', Decimal('209.25'))
# ('Tradição Hipermercados', 10249, 51, 'Manjimup Dried Apples', Decimal('2120.00'))
# ('Tradição Hipermercados', 10292, 20, "Sir Rodney's Marmalade", Decimal('1620.00'))
# ("Trail's Head Gourmet Provisioners", None, None, None, None)
# ('Vaffeljernet', 10367, 34, 'Sasquatch Ale', Decimal('504.00'))
# ('Vaffeljernet', 10367, 54, 'Tourtière', Decimal('134.10'))
# ('Vaffeljernet', 10367, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('315.75'))
# ('Vaffeljernet', 10367, 77, 'Original Frankfurter grüne Soße', Decimal('91.00'))
# ('Vaffeljernet', 10399, 68, 'Scottish Longbreads', Decimal('750.00'))
# ('Vaffeljernet', 10399, 71, 'Fløtemysost', Decimal('645.00'))
# ('Vaffeljernet', 10399, 76, 'Lakkalikööri', Decimal('630.00'))
# ('Vaffeljernet', 10399, 77, 'Original Frankfurter grüne Soße', Decimal('182.00'))
# ('Victuailles en stock', 10251, 22, "Gustaf's Knäckebröd", Decimal('126.00'))
# ('Victuailles en stock', 10251, 57, 'Ravioli Angelo', Decimal('292.50'))
# ('Victuailles en stock', 10251, 65, 'Louisiana Fiery Hot Pepper Sauce', Decimal('421.00'))
# ('Victuailles en stock', 10334, 52, 'Filo Mix', Decimal('56.00'))
# ('Victuailles en stock', 10334, 68, 'Scottish Longbreads', Decimal('125.00'))
# ('Vins et alcools Chevalier', 10274, 71, 'Fløtemysost', Decimal('430.00'))
# ('Vins et alcools Chevalier', 10274, 72, 'Mozzarella di Giovanni', Decimal('243.60'))
# ('Vins et alcools Chevalier', 10295, 56, 'Gnocchi di nonna Alice', Decimal('152.00'))
# ('Wartian Herkku', 10266, 12, 'Queso Manchego La Pastora', Decimal('456.00'))
# ('Wartian Herkku', 10270, 36, 'Inlagd Sill', Decimal('570.00'))
# ('Wartian Herkku', 10270, 43, 'Ipoh Coffee', Decimal('1150.00'))
# ('Wartian Herkku', 10320, 71, 'Fløtemysost', Decimal('645.00'))
# ('Wartian Herkku', 10333, 14, 'Tofu', Decimal('232.50'))
# ('Wartian Herkku', 10333, 21, "Sir Rodney's Scones", Decimal('100.00'))
# ('Wartian Herkku', 10333, 71, 'Fløtemysost', Decimal('860.00'))
# ('Wartian Herkku', 10412, 14, 'Tofu', Decimal('465.00'))
# ('Wartian Herkku', 10416, 19, 'Teatime Chocolate Biscuits', Decimal('184.00'))
# ('Wartian Herkku', 10416, 53, 'Perth Pasties', Decimal('328.00'))
# ('Wartian Herkku', 10416, 57, 'Ravioli Angelo', Decimal('390.00'))
# ('Wartian Herkku', 10437, 53, 'Perth Pasties', Decimal('492.00'))
# ('Wellington Importadora', 10256, 53, 'Perth Pasties', Decimal('492.00'))
# ('Wellington Importadora', 10256, 77, 'Original Frankfurter grüne Soße', Decimal('156.00'))
# ('Wellington Importadora', 10420, 9, 'Mishi Kobe Niku', Decimal('1940.00'))
# ('Wellington Importadora', 10420, 13, 'Konbu', Decimal('12.00'))
# ('Wellington Importadora', 10420, 70, 'Outback Lager', Decimal('120.00'))
# ('Wellington Importadora', 10420, 73, 'Röd Kaviar', Decimal('300.00'))
# ('White Clover Markets', 10269, 33, 'Geitost', Decimal('150.00'))
# ('White Clover Markets', 10269, 72, 'Mozzarella di Giovanni', Decimal('696.00'))
# ('White Clover Markets', 10344, 4, "Chef Anton's Cajun Seasoning", Decimal('770.00'))
# ('White Clover Markets', 10344, 8, 'Northwoods Cranberry Sauce', Decimal('2800.00'))
# ('Wilman Kala', 10248, 11, 'Queso Cabrales', Decimal('252.00'))
# ('Wilman Kala', 10248, 42, 'Singaporean Hokkien Fried Mee', Decimal('140.00'))
# ('Wilman Kala', 10248, 72, 'Mozzarella di Giovanni', Decimal('174.00'))
# ('Wolski', 10374, 31, 'Gorgonzola Telino', Decimal('375.00'))
# ('Wolski', 10374, 58, 'Escargots de Bourgogne', Decimal('198.75'))
# C:\Users\user\New folder\lib\site-packages\sqlalchemy\sql\sqltypes.py:665: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   "storage." % (dialect.name, dialect.driver)
